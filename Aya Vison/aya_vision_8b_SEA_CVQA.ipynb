# %% [markdown]
# <a href="https://colab.research.google.com/github/BosunL/SEA-VQA/blob/main/aya_vision_8b_SEA_CVQA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Visual Question Answering Example (Aya Vision 8B)
#
# This notebook demonstrates a Visual Question Answering (VQA) / Multiple-Choice Question Answering (MCQA) task using [Aya Vision 8B](https://huggingface.co/CohereForAI/aya-vision-8b), an open-weights multilingual vision-language model from Cohere Labs, loaded via the Hugging Face `transformers` library.
#
# It mirrors the structure of the BLIP VQA notebook, but swaps in Aya Vision 8B as the model and adds multilingual (English / Teso / Swahili) MCQA evaluation sourced from a Google Sheet.

# %% [markdown]
# ### Install Necessary Libraries
#
# Aya Vision requires a `transformers` build that includes support for the `AyaVision` architecture (`AutoModelForImageTextToText`). We also install `Pillow` for image processing, `torch`, `accelerate` for device placement, and `datasets`/`pandas` for loading the Google Sheet.

# %%
# Install transformers (with Aya Vision support), Pillow, torch, and other necessary libraries
# bitsandbytes is required for 4-bit quantized loading, which lets the 8B model
# fit entirely on a free-tier T4 GPU (16GB VRAM) without CPU/disk offload.
# !pip install -qqq 'git+https://github.com/huggingface/transformers.git' Pillow torch accelerate datasets pandas bitsandbytes
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 10.7 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done

# %% [markdown]
# ### Import Libraries
#
# Import the required modules from `transformers` and `PIL` (Pillow).

# %%
from transformers import AutoProcessor, AutoModelForImageTextToText, BitsAndBytesConfig
from PIL import Image
import torch
import requests
import io

# %% [markdown]
# ### Load Pre-trained Aya Vision Model and Processor
#
# We'll use the `CohereForAI/aya-vision-8b` model, an 8-billion parameter multilingual vision-language model. Note: this model is gated on Hugging Face — you'll need to accept the license on the [model page](https://huggingface.co/CohereForAI/aya-vision-8b) and authenticate (e.g. `huggingface-cli login` or `notebook_login()`) before it will download.

# %%
model_id = "CohereForAI/aya-vision-8b"

# 4-bit quantization: shrinks the model to ~5-6GB so it fits entirely on a
# T4's 16GB of VRAM. Without this, transformers silently offloads part of
# the model to CPU RAM (slow) or even disk (extremely slow) to make it fit,
# which can turn a few-second generation into a many-minute one.
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

from huggingface_hub import notebook_login
notebook_login()

processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    device_map="auto",
    quantization_config=bnb_config,
)
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>8QM2-I0S3</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>bosunl</b> (token: <code>oauth-bosunl</code>).<br>This token will be refreshed automatically when it expires.</center>
# processor_config.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/4.21k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/20.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/439 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/71.8k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/701 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/178 [00:00<?, ?B/s]

# %% [markdown]
# ### Model Evaluation
#
# In a real-world scenario, evaluating a VQA model can be done in a few ways.
#
# - **Qualitative Evaluation** (Manual Inspection): For a single example, we can simply look at the image, the question, and the model's answer to see if it makes sense.
#
# - **Quantitative Evaluation** (Using Datasets): This is a more rigorous evaluation — you would typically use a VQA benchmark dataset. Such datasets contain thousands or millions of image-question pairs, each with multiple human-annotated answers. The common metrics are:
#
# - **Accuracy**: The percentage of times the model's answer exactly matches one of the ground-truth answers.
#
# - **VQA Score**: A more nuanced metric often used in VQA challenges. For each question, if the model's answer is present in the human answers, it gets a score that's min(human_answers_count / 3, 1). This accounts for cases where multiple correct answers exist.
#
# **To perform quantitative evaluation, you would:**
#
# Load a VQA dataset.
# Iterate through the dataset, feeding each image-question pair to your model.
# Collect the model's predictions.
# Compare the predictions against the ground-truth answers using the chosen metric.

# %%
# Let's try a real world VQA model, Aya Vision, on MCQA data

import requests
from PIL import Image
import io
import os
import random
import tempfile
import matplotlib.pyplot as plt
from datasets import load_dataset
from transformers import AutoProcessor, AutoModelForImageTextToText

# %%
# ============================================================
# STEP 1: Load Model and Processor
# ============================================================
print("Loading model and processor...")

model_id = "CohereForAI/aya-vision-8b"

# 4-bit quantization: shrinks the model to ~5-6GB so it fits entirely on a
# T4's 16GB of VRAM. Without this, transformers silently offloads part of
# the model to CPU RAM (slow) or even disk (extremely slow) to make it fit —
# which is what caused earlier runs to hang for many minutes per question.
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    device_map="auto",
    quantization_config=bnb_config,
)

# Sanity check: confirm every part of the model landed on the GPU (cuda:0),
# not 'cpu' or 'disk'. If you see anything other than 0 / 'cuda:0' here,
# generation will be slow again.
print("Model device:", model.device)

print("Model loaded.\n")

# ============================================================
# Helper: run Aya Vision chat inference on a single PIL image + prompt
# ============================================================
# Aya Vision expects images via the chat template, referenced either by a
# remote URL or a local file path. Since our dataset yields PIL Image
# objects (streamed from the Google Sheet), we write each image to a
# temporary file before passing it to the processor.
_TMP_IMAGE_DIR = tempfile.mkdtemp(prefix="aya_vision_tmp_")

def generate_text(image, prompt, max_new_tokens=10):
    """
    Generate a text response from Aya Vision given a PIL image and a text prompt.

    Args:
        image (PIL.Image.Image): The input image.
        prompt (str): The text prompt to send with the image.
        max_new_tokens (int): Maximum number of new tokens to generate.

    Returns:
        str: The model's decoded text response.
    """
    tmp_path = os.path.join(_TMP_IMAGE_DIR, "frame.jpg")
    image.convert("RGB").save(tmp_path)

    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "url": tmp_path},
                {"type": "text", "text": prompt},
            ],
        }
    ]

    # NOTE: padding=True is intentionally omitted here. It's a no-op for
    # single (batch-size-1) examples like ours, and including it triggers a
    # harmless 'Kwargs passed to processor.__call__ have to be in
    # processor_kwargs...' warning in newer transformers versions.
    inputs = processor.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt",
    ).to(model.device)

    gen_tokens = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False,
    )

    decoded = processor.tokenizer.decode(
        gen_tokens[0][inputs.input_ids.shape[1]:], skip_special_tokens=True
    )
    return decoded.strip()
# Out:
# Loading model and processor...
# Loading weights:   0%|          | 0/701 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Model device: cuda:0
# Model loaded.

# %% [markdown]
# ##Using Google Drive for Direct Image Links
#
# If you prefer to use Google Drive to host your images, follow these steps to get a direct download link:
#
# 1.  **Upload your image(s)** to Google Drive.
# 2.  **Right-click** on the image file and select **'Share'**.
# 3.  In the sharing dialog, change the access from 'Restricted' to **'Anyone with the link'**.
# 4.  **Copy the shareable link**. It will look something like this:
#     `https://drive.google.com/file/d/FILE_ID/view?usp=sharing`
# 5.  **Convert the link to a direct download link** by extracting the `FILE_ID` and formatting it as:
#     `https://drive.google.com/uc?export=download&id=FILE_ID`
#
#     **Example:**
#     If your shareable link is `https://drive.google.com/file/d/1aBcDeFGhIjKlMnOpQrStUvWxYz/view?usp=sharing`,
#     your direct download link will be `https://drive.google.com/uc?export=download&id=1aBcDeFGhIjKlMnOpQrStUvWxYz`
#
# 6.  **Update your Google Sheet** with these direct download links in your `image_filename` column.

# %%
import os
import pandas as pd
from datasets import Dataset, Features, Value, Image as ImageFeature

# 1. Configuration
GOOGLE_SHEET_URL = "https://docs.google.com/spreadsheets/d/e/2PACX-1vTs9PcGM6qO4MeGzL33BtqTDhFFt7Cq4YPXolFy-lpsdHfP-yBjL_EFvyC2Saoj_AJ9dm9VT9udAJgj/pub?output=csv"
IMAGE_DIR = "/content/images/"

def clean_image_path_or_url(filename):
    """Cleans up whitespace and handles absolute web URLs or local paths."""
    if not isinstance(filename, str):
        return filename
    filename = filename.strip()

    # If it is an internet URL, use it directly. If it is a filename, prepend the folder path.
    if filename.startswith(('http://', 'https://')):
        return filename
    return os.path.join(IMAGE_DIR, filename)

# 2. Extract Data from Google Sheet
print("Fetching Google Sheet...")
df = pd.read_csv(GOOGLE_SHEET_URL)
df.columns = df.columns.str.strip()  # Clean whitespace from headers

# Ensure an Index ID column is present
if 'ID' not in df.columns:
    df['ID'] = range(1, len(df) + 1)

# 3. Map Data Structures for Lazy Loading
if 'image_filename' in df.columns:
    # Set up final resource pointers
    df['image'] = df['image_filename'].apply(clean_image_path_or_url)
    df = df.drop(columns=['image_filename'])

    # Infer metadata schema types for the text columns
    features_dict = {
        col: Value(dtype='string') if dtype == 'object' else
             Value(dtype='int64') if 'int' in str(dtype) else
             Value(dtype='float64') if 'float' in str(dtype) else
             Value(dtype='bool') if 'bool' in str(dtype) else Value(dtype='string')
        for col, dtype in df.dtypes.items() if col != 'image'
    }
    features_dict['image'] = ImageFeature()  # Stream directly from path/URL string on-the-fly

    # Instantiate the stable dataset mapping
    print("Building Hugging Face lazy-loading structure...")
    custom_dataset_from_sheet = Dataset.from_pandas(df, features=Features(features_dict))

    samples = custom_dataset_from_sheet.select(range(len(custom_dataset_from_sheet)))
    print(f"✅ Loaded {len(samples)} samples successfully. System RAM footprint: ~0 MB.")
else:
    print("❌ Error: Column 'image_filename' was not found in your Google Sheet.")
# Out:
# Fetching Google Sheet...
# Building Hugging Face lazy-loading structure...
# ✅ Loaded 51 samples successfully. System RAM footprint: ~0 MB.

# %% [markdown]
# After running this cell, `samples` will contain your data loaded from the Google Sheet, with the images processed accordingly. Remember to then run the following cell to use `custom_dataset_from_sheet` for evaluation.

# %% [markdown]
# Now, the `samples` variable contains your custom data, and the subsequent evaluation steps will use this data.

# %%
# To use your custom dataset, comment out any other dataset-loading cell and use the following:
dataset = custom_dataset_from_sheet
samples = dataset.select(range(len(custom_dataset_from_sheet)))

# %%
# ============================================================
# STEP 2: Display Sample Images
# ============================================================
print("Displaying sample images...")

# Group samples by a unique identifier for the image.
# For this task, we'll use 'Category' as a grouping key, assuming all samples
# within the same 'Category' are intended to share the same visual context.
grouped_images = {}
for i, sample in enumerate(samples):
    category = sample["Category"] # Use Category for grouping
    if category not in grouped_images:
        grouped_images[category] = {
            "image": sample["image"], # Store the actual image object
            "question_indices": []    # Store original 1-based question numbers
        }
    grouped_images[category]["question_indices"].append(i + 1)

# Determine the number of unique images to plot
num_unique_images = len(grouped_images)
# Adjust figure size dynamically based on the number of unique images
fig, axes = plt.subplots(1, num_unique_images, figsize=(5 * num_unique_images, 4))

# Ensure 'axes' is always an iterable (list) for consistent indexing, even if only one subplot
if num_unique_images == 1:
    axes = [axes]

for idx, (category, group_info) in enumerate(grouped_images.items()):
    image_to_display = group_info["image"]
    question_numbers = group_info["question_indices"]

    # Format the question numbers for the title (e.g., "Q1", "Q1-4")
    q_label = f"Q{question_numbers[0]}"
    if len(question_numbers) > 1:
        q_label += f"-{question_numbers[-1]}"

    # Create the full title including the aggregated question label and category
    full_title = f"{q_label}\n{category}"

    axes[idx].imshow(image_to_display)
    axes[idx].set_title(full_title, fontsize=8)
    axes[idx].axis("off")

plt.suptitle("CVQA Images (English/Teso/Swahili)", fontsize=12)
plt.tight_layout()
plt.show()

# %%
def build_mcqa_prompt(question, choices):
    """
    Format question + choices into a prompt.
    Instructs the model to answer with only a letter A/B/C/D.
    """
    prompt = (
        "Look at the image carefully and answer the following "
        "multiple choice question by selecting only the letter "
        "A, B, C, or D.\n\n"
        f"Question: {question}\n"
    )
    for label, choice in zip(["A", "B", "C", "D"], choices):
        prompt += f"{label}. {choice}\n"
    prompt += "\nAnswer with only the letter (A, B, C, or D):"
    return prompt

def extract_predicted_label(predicted_text, choices):
    """
    Extract the predicted label (A/B/C/D) from model output.

    Strategy 1: look for A/B/C/D letter in model output.
    Strategy 2: if no letter found, check if model output
                matches any choice text directly.
    If no label is found, defaults to a random choice (A,B,C,D) to ensure a prediction is always made.
    """
    # Strategy 1 — look for letter
    for label in ["A", "B", "C", "D"]:
        if label in predicted_text.upper():
            return label

    # Strategy 2 — match answer text
    for label, choice in zip(["A", "B", "C", "D"], choices):
        if choice.lower() in predicted_text.lower():
            return label

    # Default to a random choice if no label is found
    import random
    return random.choice(["A", "B", "C", "D"])

# %% [markdown]
# ### Extend Evaluation to Teso and Swahili Questions
#
# Now, we'll extend the evaluation to also process questions in Teso and Swahili. This requires specifying the column names in your Google Sheet that contain the localized questions and their corresponding choices. The `evaluate_sea_mcqa` function will be updated to evaluate English, Teso, and Swahili questions for each sample.
#
# First, define the Teso- and Swahili-related column names here:

# %%
# Define column names for Teso questions and answers
TESO_QUESTION_COLUMN = "native_question"
TESO_CORRECT_ANSWER_COLUMN = "correct_native"
TESO_WRONG_ANSWER_COLUMNS = ["wrong_native_o1", "wrong_native_o2", "wrong_native_o3"]

print(f"Teso Question Column: {TESO_QUESTION_COLUMN}")
print(f"Teso Correct Answer Column: {TESO_CORRECT_ANSWER_COLUMN}")
print(f"Teso Wrong Answer Columns: {TESO_WRONG_ANSWER_COLUMNS}")

print("\n")

# Define column names for Swahili questions and answers
SWA_QUESTION_COLUMN = "swa_question"
SWA_CORRECT_ANSWER_COLUMN = "correct_swa"
SWA_WRONG_ANSWER_COLUMNS = ["wrong_swa_o1", "wrong_swa_o2", "wrong_swa_o3"]

print(f"Swahili Question Column: {SWA_QUESTION_COLUMN}")
print(f"Swahili Correct Answer Column: {SWA_CORRECT_ANSWER_COLUMN}")
print(f"Swahili Wrong Answer Columns: {SWA_WRONG_ANSWER_COLUMNS}")
# Out:
# Teso Question Column: native_question
# Teso Correct Answer Column: correct_native
# Teso Wrong Answer Columns: ['wrong_native_o1', 'wrong_native_o2', 'wrong_native_o3']
#
#
# Swahili Question Column: swa_question
# Swahili Correct Answer Column: correct_swa
# Swahili Wrong Answer Columns: ['wrong_swa_o1', 'wrong_swa_o2', 'wrong_swa_o3']

# %% [markdown]
# Now, the `evaluate_sea_mcqa` function processes English, Teso, and Swahili questions for each sample using Aya Vision's chat template via `generate_text`. The results include a `language` field to distinguish between them.

# %%
# ============================================================
# STEP 3: Run Evaluation (Trilingual, Aya Vision 8B)
# ============================================================
import time

def _get_row_with_retry(samples, idx, max_retries=4, base_delay=5):
    """
    Fetch samples[idx] with retries. This is important because accessing a
    row from a `datasets.Dataset` built on a lazy Image feature triggers the
    actual image download/decode right here — NOT later when you explicitly
    touch sample['image']. A slow or flaky image URL (e.g. Google Drive) can
    raise a network timeout (httpx.ReadTimeout) at this exact point, outside
    of any try/except placed later in the loop body. Without a retry wrapper
    around this specific access, a single bad image kills the entire run.
    """
    last_err = None
    for attempt in range(1, max_retries + 1):
        try:
            return samples[idx]
        except Exception as e:
            last_err = e
            wait = base_delay * attempt
            print(f"  [Row {idx+1}] fetch attempt {attempt}/{max_retries} failed "
                  f"({type(e).__name__}: {e}). Retrying in {wait}s...", flush=True)
            time.sleep(wait)
    print(f"  [Row {idx+1}] giving up after {max_retries} attempts "
          f"({type(last_err).__name__}: {last_err}). Skipping this row.", flush=True)
    return None

def evaluate_sea_mcqa(samples, teso_question_col, teso_correct_ans_col, teso_wrong_ans_cols,
                       swa_question_col, swa_correct_ans_col, swa_wrong_ans_cols):
    """
    Evaluate Aya Vision on SEA-MCQA for English, Teso, and Swahili questions.
    Accuracy = % of samples where model selects the correct option.
    Random chance baseline = 25% (4 choices).
    """
    predictions = []
    skipped_rows = []
    total_rows = len(samples)

    # image is loaded ONCE per row (not once per language) and passed in,
    # since sample['image'] is a lazy datasets.Image feature that re-fetches
    # from its source URL/path on every access. Re-fetching it 3x per row
    # (once per language) was the main hidden cause of slow runs, especially
    # with Google Drive-hosted images.
    def _evaluate_single_question_language(sample, image, question_col, correct_ans_col, wrong_ans_cols, language_tag):
        question    = sample[question_col]
        correct_ans = sample[correct_ans_col]
        wrong_1     = sample[wrong_ans_cols[0]]
        wrong_2     = sample[wrong_ans_cols[1]]
        wrong_3     = sample[wrong_ans_cols[2]]

        # Shuffle choices so correct answer isn't always in same position
        choices = [correct_ans, wrong_1, wrong_2, wrong_3]
        random.shuffle(choices)
        correct_label = ["A", "B", "C", "D"][choices.index(correct_ans)]

        # Build prompt
        prompt = build_mcqa_prompt(question, choices)

        predicted_text = "ERROR"
        predicted_label = None
        is_correct = False

        try:
            # Run Aya Vision via its chat template
            predicted_text = generate_text(image, prompt, max_new_tokens=10)

            # Extract predicted label using both strategies
            predicted_label = extract_predicted_label(predicted_text, choices)

            # Check correctness
            is_correct = (predicted_label == correct_label)

        except Exception as e:
            print(f"  Error processing sample ID {sample['ID']} ({language_tag} question): {e}")

        return {
            "sample_id":       sample["ID"],
            "category":        sample["Category"],
            "language":        language_tag,
            "question":        question,
            "choices":         {l: c for l, c in zip(["A","B","C","D"], choices)},
            "correct_answer":  correct_ans,
            "correct_label":   correct_label,
            "predicted_text":  predicted_text,
            "predicted_label": predicted_label,
            "is_correct":      is_correct
        }

    run_start = time.time()
    for i in range(total_rows):
        row_start = time.time()
        print(f"[Row {i+1}/{total_rows}] fetching row...", flush=True)

        # Fetch the row itself with retries — this is where the image
        # download/decode actually happens for a lazy datasets.Image feature.
        sample = _get_row_with_retry(samples, i)
        if sample is None:
            skipped_rows.append(i + 1)
            continue

        try:
            image = sample["image"].convert("RGB")
        except Exception as e:
            print(f"  Failed to convert image for row {i+1} (ID={sample.get('ID')}): {e}. Skipping.", flush=True)
            skipped_rows.append(i + 1)
            continue

        img_load_time = time.time() - row_start
        print(f"  Row {i+1} ID={sample['ID']} ({sample['Category']}) ready in {img_load_time:.1f}s. "
              f"Running English/Teso/Swahili questions...", flush=True)

        # Evaluate English question
        english_prediction = _evaluate_single_question_language(
            sample, image, "eng_question", "correct_en",
            ["wrong_en_o1", "wrong_en_o2", "wrong_en_o3"], "English"
        )
        predictions.append(english_prediction)

        # Evaluate Teso question
        teso_prediction = _evaluate_single_question_language(
            sample, image, teso_question_col, teso_correct_ans_col,
            teso_wrong_ans_cols, "Teso"
        )
        predictions.append(teso_prediction)

        # Evaluate Swahili question
        swa_prediction = _evaluate_single_question_language(
            sample, image, swa_question_col, swa_correct_ans_col,
            swa_wrong_ans_cols, "Swahili"
        )
        predictions.append(swa_prediction)

        row_time = time.time() - row_start
        elapsed = time.time() - run_start
        avg_per_row = elapsed / (i + 1)
        remaining = avg_per_row * (total_rows - (i + 1))
        print(f"  Row {i+1}/{total_rows} done in {row_time:.1f}s. "
              f"Elapsed: {elapsed/60:.1f} min. Est. remaining: {remaining/60:.1f} min.\n", flush=True)

    overall_correct = sum(p['is_correct'] for p in predictions)
    overall_accuracy = (overall_correct / len(predictions)) * 100 if predictions else 0

    if skipped_rows:
        print(f"\nWARNING: skipped {len(skipped_rows)} row(s) after repeated fetch failures: {skipped_rows}\n")

    return overall_accuracy, predictions

# Call the evaluation function
accuracy, detailed_predictions = evaluate_sea_mcqa(
    samples,
    TESO_QUESTION_COLUMN, TESO_CORRECT_ANSWER_COLUMN, TESO_WRONG_ANSWER_COLUMNS,
    SWA_QUESTION_COLUMN, SWA_CORRECT_ANSWER_COLUMN, SWA_WRONG_ANSWER_COLUMNS
)

print("Evaluation complete for English, Teso, and Swahili questions.")
# Out:
# [Row 1/51] fetching row...
#   Row 1 ID=1 (Image 1 Questions) ready in 4.9s. Running English/Teso/Swahili questions...
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
#   Row 1/51 done in 20.2s. Elapsed: 0.3 min. Est. remaining: 16.9 min.
#
# [Row 2/51] fetching row...
#   Row 2 ID=2 (Image 1 Questions) ready in 3.3s. Running English/Teso/Swahili questions...
#   Row 2/51 done in 16.9s. Elapsed: 0.6 min. Est. remaining: 15.2 min.
#
# [Row 3/51] fetching row...
#   Row 3 ID=3 (Image 1 Questions) ready in 3.3s. Running English/Teso/Swahili questions...
#   Row 3/51 done in 17.1s. Elapsed: 0.9 min. Est. remaining: 14.5 min.
#
# [Row 4/51] fetching row...
#   Row 4 ID=4 (Image 1 Questions) ready in 3.5s. Running English/Teso/Swahili questions...
#   Row 4/51 done in 17.1s. Elapsed: 1.2 min. Est. remaining: 14.0 min.
#
# [Row 5/51] fetching row...
#   Row 5 ID=5 (Image 2 Questions) ready in 2.4s. Running English/Teso/Swahili questions...
#   Row 5/51 done in 17.3s. Elapsed: 1.5 min. Est. remaining: 13.6 min.
#
# [Row 6/51] fetching row...
#   Row 6 ID=6 (Image 2 Questions) ready in 2.3s. Running English/Teso/Swahili questions...
#   Row 6/51 done in 17.1s. Elapsed: 1.8 min. Est. remaining: 13.2 min.
#
# [Row 7/51] fetching row...
#   Row 7 ID=7 (Image 2 Questions) ready in 2.5s. Running English/Teso/Swahili questions...
#   Row 7/51 done in 16.6s. Elapsed: 2.0 min. Est. remaining: 12.8 min.
#
# [Row 8/51] fetching row...
#   Row 8 ID=8 (Image 2 Questions) ready in 2.5s. Running English/Teso/Swahili questions...
#   Row 8/51 done in 16.8s. Elapsed: 2.3 min. Est. remaining: 12.5 min.
#
# [Row 9/51] fetching row...
#   Row 9 ID=9 (Image 3 Questions) ready in 3.2s. Running English/Teso/Swahili questions...
#   Row 9/51 done in 16.2s. Elapsed: 2.6 min. Est. remaining: 12.1 min.
#
# [Row 10/51] fetching row...
#   Row 10 ID=10 (Image 3 Questions) ready in 2.7s. Running English/Teso/Swahili questions...
#   Row 10/51 done in 14.7s. Elapsed: 2.8 min. Est. remaining: 11.6 min.
#
# [Row 11/51] fetching row...
#   Row 11 ID=11 (Image 3 Questions) ready in 3.1s. Running English/Teso/Swahili questions...
#   Row 11/51 done in 16.2s. Elapsed: 3.1 min. Est. remaining: 11.3 min.
#
# [Row 12/51] fetching row...
#   Row 12 ID=12 (Image 4 Questions) ready in 3.5s. Running English/Teso/Swahili questions...
#   Row 12/51 done in 16.9s. Elapsed: 3.4 min. Est. remaining: 11.0 min.
#
# [Row 13/51] fetching row...
#   Row 13 ID=13 (Image 4 Questions) ready in 3.9s. Running English/Teso/Swahili questions...
#   Row 13/51 done in 16.9s. Elapsed: 3.7 min. Est. remaining: 10.7 min.
#
# [Row 14/51] fetching row...
#   Row 14 ID=14 (Image 4 Questions) ready in 3.9s. Running English/Teso/Swahili questions...
#   Row 14/51 done in 16.9s. Elapsed: 3.9 min. Est. remaining: 10.4 min.
#
# [Row 15/51] fetching row...
#   Row 15 ID=15 (Image 4 Questions) ready in 3.2s. Running English/Teso/Swahili questions...
#   Row 15/51 done in 16.4s. Elapsed: 4.2 min. Est. remaining: 10.1 min.
#
# [Row 16/51] fetching row...
#   Row 16 ID=16 (Image 5 Questions) ready in 3.7s. Running English/Teso/Swahili questions...
#   Row 16/51 done in 18.4s. Elapsed: 4.5 min. Est. remaining: 9.9 min.
#
# [Row 17/51] fetching row...
#   Row 17 ID=17 (Image 5 Questions) ready in 4.2s. Running English/Teso/Swahili questions...
#   Row 17/51 done in 17.7s. Elapsed: 4.8 min. Est. remaining: 9.6 min.
#
# [Row 18/51] fetching row...
#   Row 18 ID=18 (Image 5 Questions) ready in 4.4s. Running English/Teso/Swahili questions...
#   Row 18/51 done in 19.9s. Elapsed: 5.2 min. Est. remaining: 9.4 min.
#
# [Row 19/51] fetching row...
#   Row 19 ID=19 (Image 5 Questions) ready in 4.2s. Running English/Teso/Swahili questions...
#   Row 19/51 done in 17.7s. Elapsed: 5.4 min. Est. remaining: 9.2 min.
#
# [Row 20/51] fetching row...
#   Row 20 ID=20 (Image 6 Questions) ready in 2.4s. Running English/Teso/Swahili questions...
#   Error processing sample ID 20 (English question): CUDA out of memory. Tried to allocate 272.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 153.81 MiB is free. Including non-PyTorch memory, this process has 14.41 GiB memory in use. Of the allocated memory 13.70 GiB is allocated by PyTorch, and 593.55 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Error processing sample ID 20 (Teso question): CUDA out of memory. Tried to allocate 290.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 85.81 MiB is free. Including non-PyTorch memory, this process has 14.48 GiB memory in use. Of the allocated memory 13.85 GiB is allocated by PyTorch, and 510.82 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Error processing sample ID 20 (Swahili question): CUDA out of memory. Tried to allocate 300.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 47.81 MiB is free. Including non-PyTorch memory, this process has 14.51 GiB memory in use. Of the allocated memory 13.92 GiB is allocated by PyTorch, and 468.90 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Row 20/51 done in 5.0s. Elapsed: 5.5 min. Est. remaining: 8.6 min.
#
# [Row 21/51] fetching row...
#   Row 21 ID=21 (Image 6 Questions) ready in 2.3s. Running English/Teso/Swahili questions...
#   Error processing sample ID 21 (English question): CUDA out of memory. Tried to allocate 288.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 47.81 MiB is free. Including non-PyTorch memory, this process has 14.51 GiB memory in use. Of the allocated memory 13.83 GiB is allocated by PyTorch, and 565.29 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Error processing sample ID 21 (Teso question): CUDA out of memory. Tried to allocate 292.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 47.81 MiB is free. Including non-PyTorch memory, this process has 14.51 GiB memory in use. Of the allocated memory 13.87 GiB is allocated by PyTorch, and 527.92 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Error processing sample ID 21 (Swahili question): CUDA out of memory. Tried to allocate 310.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 3.81 MiB is free. Including non-PyTorch memory, this process has 14.56 GiB memory in use. Of the allocated memory 14.02 GiB is allocated by PyTorch, and 418.13 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Row 21/51 done in 4.6s. Elapsed: 5.6 min. Est. remaining: 8.0 min.
#
# [Row 22/51] fetching row...
#   Row 22 ID=22 (Image 6 Questions) ready in 2.3s. Running English/Teso/Swahili questions...
#   Error processing sample ID 22 (English question): CUDA out of memory. Tried to allocate 254.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 3.81 MiB is free. Including non-PyTorch memory, this process has 14.56 GiB memory in use. Of the allocated memory 13.55 GiB is allocated by PyTorch, and 900.65 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Error processing sample ID 22 (Teso question): CUDA out of memory. Tried to allocate 256.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 3.81 MiB is free. Including non-PyTorch memory, this process has 14.56 GiB memory in use. Of the allocated memory 13.56 GiB is allocated by PyTorch, and 884.12 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Error processing sample ID 22 (Swahili question): CUDA out of memory. Tried to allocate 258.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 3.81 MiB is free. Including non-PyTorch memory, this process has 14.56 GiB memory in use. Of the allocated memory 13.58 GiB is allocated by PyTorch, and 863.00 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#   Row 22/51 done in 4.6s. Elapsed: 5.7 min. Est. remaining: 7.5 min.
#
# [Row 23/51] fetching row...
#   Row 23 ID=23 (Image 7 Questions) ready in 3.5s. Running English/Teso/Swahili questions...
#   Row 23/51 done in 16.1s. Elapsed: 6.0 min. Est. remaining: 7.2 min.
#
# [Row 24/51] fetching row...
#   Row 24 ID=24 (Image 7 Questions) ready in 3.1s. Running English/Teso/Swahili questions...
#   Row 24/51 done in 15.4s. Elapsed: 6.2 min. Est. remaining: 7.0 min.
#
# [Row 25/51] fetching row...
#   Row 25 ID=25 (Image 7 Questions) ready in 3.2s. Running English/Teso/Swahili questions...
#   Row 25/51 done in 16.9s. Elapsed: 6.5 min. Est. remaining: 6.7 min.
#
# [Row 26/51] fetching row...
#   Row 26 ID=26 (Image 8 Questions) ready in 3.0s. Running English/Teso/Swahili questions...
#   Row 26/51 done in 15.0s. Elapsed: 6.7 min. Est. remaining: 6.5 min.
#
# [Row 27/51] fetching row...
#   Row 27 ID=27 (Image 8 Questions) ready in 2.9s. Running English/Teso/Swahili questions...
#   Row 27/51 done in 16.3s. Elapsed: 7.0 min. Est. remaining: 6.2 min.
#
# [Row 28/51] fetching row...
#   Row 28 ID=28 (Image 8 Questions) ready in 2.9s. Running English/Teso/Swahili questions...
#   Row 28/51 done in 16.6s. Elapsed: 7.3 min. Est. remaining: 6.0 min.
#
# [Row 29/51] fetching row...
#   Row 29 ID=29 (Image 9 Questions) ready in 2.7s. Running English/Teso/Swahili questions...
#   Row 29/51 done in 15.0s. Elapsed: 7.5 min. Est. remaining: 5.7 min.
#
# [Row 30/51] fetching row...
#   Row 30 ID=30 (Image 9 Questions) ready in 2.7s. Running English/Teso/Swahili questions...
#   Row 30/51 done in 15.2s. Elapsed: 7.8 min. Est. remaining: 5.5 min.
#
# [Row 31/51] fetching row...
#   Row 31 ID=31 (Image 9 Questions) ready in 2.6s. Running English/Teso/Swahili questions...
#   Row 31/51 done in 15.3s. Elapsed: 8.0 min. Est. remaining: 5.2 min.
#
# [Row 32/51] fetching row...
#   Row 32 ID=32 (Image 9 Questions) ready in 2.9s. Running English/Teso/Swahili questions...
#   Row 32/51 done in 15.8s. Elapsed: 8.3 min. Est. remaining: 4.9 min.
#
# [Row 33/51] fetching row...
#   Row 33 ID=33 (Image 10 Questions) ready in 4.2s. Running English/Teso/Swahili questions...
#   Row 33/51 done in 19.5s. Elapsed: 8.6 min. Est. remaining: 4.7 min.
#
# [Row 34/51] fetching row...
#   Row 34 ID=34 (Image 10 Questions) ready in 4.2s. Running English/Teso/Swahili questions...
#   Row 34/51 done in 17.4s. Elapsed: 8.9 min. Est. remaining: 4.5 min.
#
# [Row 35/51] fetching row...
#   Row 35 ID=35 (Image 10 Questions) ready in 4.3s. Running English/Teso/Swahili questions...
#   Row 35/51 done in 17.7s. Elapsed: 9.2 min. Est. remaining: 4.2 min.
#
# [Row 36/51] fetching row...
#   Row 36 ID=36 (Image 10 Questions) ready in 4.0s. Running English/Teso/Swahili questions...
#   Row 36/51 done in 17.7s. Elapsed: 9.5 min. Est. remaining: 4.0 min.
#
# [Row 37/51] fetching row...
#   Row 37 ID=37 (Image 10 Questions) ready in 4.4s. Running English/Teso/Swahili questions...
#   Row 37/51 done in 17.9s. Elapsed: 9.8 min. Est. remaining: 3.7 min.
#
# [Row 38/51] fetching row...
#   Row 38 ID=38 (Image 11 Questions) ready in 3.6s. Running English/Teso/Swahili questions...
#   Row 38/51 done in 16.0s. Elapsed: 10.1 min. Est. remaining: 3.4 min.
#
# [Row 39/51] fetching row...
#   Row 39 ID=39 (Image 11 Questions) ready in 3.5s. Running English/Teso/Swahili questions...
#   Row 39/51 done in 16.1s. Elapsed: 10.3 min. Est. remaining: 3.2 min.
#
# [Row 40/51] fetching row...
#   Row 40 ID=40 (Image 11 Questions) ready in 2.9s. Running English/Teso/Swahili questions...
#   Row 40/51 done in 16.5s. Elapsed: 10.6 min. Est. remaining: 2.9 min.
#
# [Row 41/51] fetching row...
#   Row 41 ID=41 (Image 12 Questions) ready in 3.3s. Running English/Teso/Swahili questions...
#   Row 41/51 done in 15.8s. Elapsed: 10.9 min. Est. remaining: 2.7 min.
#
# [Row 42/51] fetching row...
#   Row 42 ID=42 (Image 12 Questions) ready in 3.3s. Running English/Teso/Swahili questions...
#   Row 42/51 done in 15.4s. Elapsed: 11.1 min. Est. remaining: 2.4 min.
#
# [Row 43/51] fetching row...
#   Row 43 ID=43 (Image 12 Questions) ready in 3.1s. Running English/Teso/Swahili questions...
#   Row 43/51 done in 15.3s. Elapsed: 11.4 min. Est. remaining: 2.1 min.
#
# [Row 44/51] fetching row...
#   Row 44 ID=44 (Image 13 Questions) ready in 3.3s. Running English/Teso/Swahili questions...
#   Row 44/51 done in 15.6s. Elapsed: 11.7 min. Est. remaining: 1.9 min.
#
# [Row 45/51] fetching row...
#   Row 45 ID=45 (Image 13 Questions) ready in 3.3s. Running English/Teso/Swahili questions...
#   Row 45/51 done in 15.7s. Elapsed: 11.9 min. Est. remaining: 1.6 min.
#
# [Row 46/51] fetching row...
#   Row 46 ID=46 (Image 13 Questions) ready in 3.3s. Running English/Teso/Swahili questions...
#   Row 46/51 done in 15.6s. Elapsed: 12.2 min. Est. remaining: 1.3 min.
#
# [Row 47/51] fetching row...
#   Row 47 ID=47 (Image 13 Questions) ready in 3.1s. Running English/Teso/Swahili questions...
#   Row 47/51 done in 15.2s. Elapsed: 12.4 min. Est. remaining: 1.1 min.
#
# [Row 48/51] fetching row...
#   Row 48 ID=48 (Image 14 Questions) ready in 3.0s. Running English/Teso/Swahili questions...
#   Row 48/51 done in 15.1s. Elapsed: 12.7 min. Est. remaining: 0.8 min.
#
# [Row 49/51] fetching row...
#   Row 49 ID=49 (Image 14 Questions) ready in 3.0s. Running English/Teso/Swahili questions...
#   Row 49/51 done in 15.3s. Elapsed: 12.9 min. Est. remaining: 0.5 min.
#
# [Row 50/51] fetching row...
#   Row 50 ID=50 (Image 14 Questions) ready in 2.9s. Running English/Teso/Swahili questions...
#   Row 50/51 done in 14.9s. Elapsed: 13.2 min. Est. remaining: 0.3 min.
#
# [Row 51/51] fetching row...
#   Row 51 ID=51 (Image 14 Questions) ready in 2.9s. Running English/Teso/Swahili questions...
#   Row 51/51 done in 15.5s. Elapsed: 13.4 min. Est. remaining: 0.0 min.
#
# Evaluation complete for English, Teso, and Swahili questions.

# %% [markdown]
# ### Print Results (Trilingual)
#
# This section displays the detailed evaluation results for English, Teso, and Swahili questions.

# %%
# ============================================================
# STEP 4: Print Results (Trilingual)
# ============================================================
print("\n" + "="*60)
print("     MCQA Evaluation Results — Aya Vision 8B (English, Teso, Swahili)")
print("="*60)

correct_english = sum(p['is_correct'] for p in detailed_predictions if p['language'] == 'English')
total_english = sum(1 for p in detailed_predictions if p['language'] == 'English')
accuracy_english = (correct_english / total_english) * 100 if total_english else 0

correct_teso = sum(p['is_correct'] for p in detailed_predictions if p['language'] == 'Teso')
total_teso = sum(1 for p in detailed_predictions if p['language'] == 'Teso')
accuracy_teso = (correct_teso / total_teso) * 100 if total_teso else 0

correct_swa = sum(p['is_correct'] for p in detailed_predictions if p['language'] == 'Swahili')
total_swa = sum(1 for p in detailed_predictions if p['language'] == 'Swahili')
accuracy_swa = (correct_swa / total_swa) * 100 if total_swa else 0

for i, pred in enumerate(detailed_predictions, 1):
    status = "✓" if pred["is_correct"] else "✗"
    print(f"\n[{status}] Q{pred['sample_id']} ({pred['language']}) [{pred['category']}]")
    print(f"  Question: {pred['question']}")
    for label, choice in pred["choices"].items():
        marker = " ← correct" if choice == pred["correct_answer"] else ""
        print(f"  {label}. {choice}{marker}")
    print(f"  Model output:    {pred['predicted_text']}")
    print(f"  Predicted label: {pred['predicted_label']}  "
          f"|  Correct label: {pred['correct_label']}")

print("\n" + "="*60)
print(f"Overall Accuracy:        {accuracy:.2f}% ({sum(p['is_correct'] for p in detailed_predictions)}/{len(detailed_predictions)}) ")
print(f"English Accuracy:        {accuracy_english:.2f}% ({correct_english}/{total_english})")
print(f"Teso Accuracy:           {accuracy_teso:.2f}% ({correct_teso}/{total_teso})")
print(f"Swahili Accuracy:        {accuracy_swa:.2f}% ({correct_swa}/{total_swa})")
print(f"Random chance baseline:  25.00% (4 choices)")
print("="*60)
# Out:
# ============================================================
#      MCQA Evaluation Results — Aya Vision 8B (English, Teso, Swahili)
# ============================================================
#
# [✓] Q1 (English) [Image 1 Questions]
#   Question: Which of the baskets are pictured, what are they called in this country, and what is their purpose?
#   A. Emotokaa. Kanueraitere nakapoloni itomate adakia inyamata luipwaka katoni luitijimete inyamene ayari namakegwelete
#   B. Uteo. Crafted from reeds or palm leaves. It is traditionally found in households and was used to separate the chaff from grain.Its commonly used to hold cereals, in market places, and in homes. ← correct
#   C. Bolga baskets. Made from thick, dried elephant grass. They are also very durable because of the tight weaving and are used as market or beach bags, home decor, and for storage and organization.
#   D. Mesob baskets. Individual strands of grass or palm are dyed with vibrant colors and utilized for communal serving holding traditional meals
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✗] Q1 (Teso) [Image 1 Questions]
#   Question: Ibukito alu ajsii aputo, enayrit kesi nyena kakwap kalo? Inyena nesii asoma kesii?
#   A. Ibukit luka mesob. Anyart apee akou kanyaiti kape isutite, iranginino luchaete na itomayo akiria kadakite inyamene katikere
#   B. Euderu. Ejeo kaladoi kiton amusogon edumunun  kotogoi lukalong itosomao akipiet inyamen Itosomao adakite eariot kosokoni katoni kore ← correct
#   C. Ibukito luka bolga. Ejeo kesi alumni kosere kaleoburo cuti. Ichasit kesi aso iboete cuti aoaki neuja.  Asoma kesi kogwelete kanamikwangere akilimia itogoi, akigwa iboro,  katoni atongitongoi
#   D. Eguniati ngoli titosmomao akitowonio ichoko luepelel ingarakini akitene ichoko lukakiraa kotetenyi alumni iraito lukejoka
#   Model output:    C
#   Predicted label: C  |  Correct label: B
#
# [✗] Q1 (Swahili) [Image 1 Questions]
#   Question: Ni vikapu gani kati ya hivyo vilivyoonyeshwa, vinaitwaje katika nchi hii, na kusudi lao ni lipi?
#   A. Emotokaa. Kanueraitere nakapoloni itomate adakia inyamata luipwaka katoni luitijimete inyamene ayari namakegwelete.
#   B. Vikapu vya Mesob. Vipande vya nyasi au mitende hupakwa rangi angavu na hutumika kwa huduma ya pamoja ya kuandalia milo ya kitamaduni.
#   C. Vikapu vya Bolga. Vimetengenezwa kwa nyasi nene na kavu. Pia ni vya kudumu sana kwa sababu ya kusuka kwa ukali na hutumika kama mifuko ya sokoni au ufukweni, mapambo ya nyumbani, na kwa ajili ya kuhifadhi na kupanga.
#   D. Uteo. Imetengenezwa kwa matete au majani ya mitende. Kijadi hupatikana majumbani na ilitumika kutenganisha makapi na nafaka. Kwa kawaida hutumika kuhifadhi nafaka, sokoni, na majumbani. ← correct
#   Model output:    C
#   Predicted label: C  |  Correct label: D
#
# [✓] Q2 (English) [Image 1 Questions]
#   Question: What are the yellow jerry cans used for?
#   A. Easy transportation of baskets
#   B. Storage of cooking oils, water, and cereals ← correct
#   C. They are used to store dough
#   D. Prolong the shelf life of fresh fish and raw meat
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✓] Q2 (Teso) [Image 1 Questions]
#   Question: Inyena asoma kejerikana nukobegete
#   A. Akituuja akijara kikole luepalala ka kiringi
#   B. Etapana adakari ibukito
#   C. Akigwa akinyet kedia, akipii katoni inyamet luewokito ← correct
#   D. Itosomao akigwa akiria nu esudite
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✓] Q2 (Swahili) [Image 1 Questions]
#   Question: Makopo ya njano ya jerry hutumika kwa ajili ya nini?
#   A. Uhifadhi wa mafuta ya kupikia, maji, na nafaka ← correct
#   B. Zinatumika kuhifadhi unga
#   C. Usafirishaji rahisi wa vikapu
#   D. Ongeza muda wa matumizi ya samaki mbichi na nyama mbichi
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✓] Q3 (English) [Image 1 Questions]
#   Question: What form of transportation is common for small-scale market vendors?
#   A. Car. Since it’s the biggest, market vendors often transport mass amounts of food and spices from recent harvest to sale at the market.
#   B. Bicycle. It is highly affordable since it doesn't depend on fuel. It easily carries smaller harvests to the market, allowing vendors to sell their goods and travel light on the way back. ← correct
#   C. Tuktuk. It is affordable and allows for easy transport of many items.
#   D. Boda-boda. The two-wheeled motorcycle or bicycle taxi allows for quickest transport to waiting customers and are found in many rural and urban areas.
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✓] Q3 (Teso) [Image 1 Questions]
#   Question: Inyena itosomaete itugna adakaia iboro kogwelete kaluchisi.
#   A. Ebodaboda. Eraiti achakadu ikokorori kiyare kere  akarigo na elosi katipe noi. Itosomate kitunga kalidarito alosite. Edumuni cuti kochalo kaoni otauni.
#   B. Atuktuk. Itapana  etachiti kene na  etapana adakia iboro luepu.
#   C. Akarigo. Atapana cuti akitosom kanukamum akinyet . Edaki idwenyana idisi na elosete itunga lukegwelete katapan abongori ore. ← correct
#   D. Emotokaa. Kanueraitere nakapoloni itomate adakia inyamata luipwaka katoni luitijimete inyamene ayari namakegwelete
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✓] Q3 (Swahili) [Image 1 Questions]
#   Question: Ni aina gani ya usafiri ambayo ni ya kawaida kwa wachuuzi wadogo wa soko?
#   A. Gari. Kwa kuwa ndilo kubwa zaidi, wachuuzi wa soko mara nyingi husafirisha kiasi kikubwa cha chakula na viungo kutoka kwa mavuno ya hivi karibuni hadi mauzo sokoni.
#   B. Baiskeli. Ni nafuu sana kwa sababu haitegemei mafuta. Inasafirisha mavuno madogo sokoni kwa urahisi, na hivyo kuruhusu wachuuzi kuuza bidhaa zao na kusafiri kwa urahisi wanaporudi. ← correct
#   C. Boda-boda. Pikipiki au teksi ya baiskeli yenye magurudumu mawili inaruhusu usafiri wa haraka zaidi kwa wateja wanaosubiri na inapatikana katika maeneo mengi ya vijijini na mijini.
#   D. Tuktuk. Ni nafuu na inaruhusu usafirishaji rahisi wa vitu vingi.
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✓] Q4 (English) [Image 1 Questions]
#   Question: What is the significance of the sack?
#   A. The sack is often used to store cassava and maize. The bags can be made from plastic and a tightly woven outer layer. ← correct
#   B. The sack is used for drying wet seeds. It helps prepare the seeds to be planted, leading to better quality crops.
#   C. The sack is frequently used to hold rice, which is cooked as a daily meal and mass-produced.
#   D. The sack usually hold dried beans and better preserves nutrients and quality.
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✗] Q4 (Teso) [Image 1 Questions]
#   Question: Nyena adumunet kegunieti?
#   A. Eguniati ngoli titosmomao akitowonio ichoko luepelel ingarakini akitene ichoko lukakiraa kotetenyi alumni iraito lukejoka
#   B. Eguniati Etosomao akidaka emuchere loipoyo nginiparan kapolou
#   C. Eguniati kachuti edakiti amaragwe nakaoni kakigwa tenan
#   D. Eguniete etosomao akigwa emogo kekurididi. Itenio kaplastic katoni namaejaite kokinga baba ← correct
#   Model output:    A
#   Predicted label: A  |  Correct label: D
#
# [✗] Q4 (Swahili) [Image 1 Questions]
#   Question: Umuhimu wa gunia ni upi?
#   A. Gunia hutumika kukaushia mbegu zenye unyevu. Husaidia kuandaa mbegu za kupanda, na hivyo kusababisha mazao bora zaidi.
#   B. Gunia mara nyingi hutumika kuhifadhi mihogo na mahindi. Mifuko inaweza kutengenezwa kwa plastiki na safu ya nje iliyosokotwa vizuri. ← correct
#   C. Gunia hilo hutumika mara nyingi kuhifadhi wali, ambao hupikwa kama mlo wa kila siku na hutengenezwa kwa wingi.
#   D. Kwa kawaida gunia huhifadhi maharagwe makavu na huhifadhi virutubisho na ubora zaidi.
#   Model output:    A
#   Predicted label: A  |  Correct label: B
#
# [✗] Q5 (English) [Image 2 Questions]
#   Question: The blue container in the top right corner holds many dried, chipped pieces of a particular food. What food is made from this material, and what process was used to get to this point?
#   A. Chips. They are sliced into thin pieces, baked in an oven at a high heat until all of their moisture is gone, then dipped in water to cool off.
#   B. Bread. They are battered in flour, dipped in frying oil, and then let rest until they are cooled.
#   C. Fried rice. The uncooked grains are laid in a row, flattened with a roller, and boiled.
#   D. Porridge. It is laid on the floor in thin layers on top of a cloth, left to be sundried, and then broken up into smaller pieces. ← correct
#   Model output:    A
#   Predicted label: A  |  Correct label: D
#
# [✓] Q5 (Teso) [Image 2 Questions]
#   Question: Abesin nejii kowai kamaa kateten erumit inyamat. Inyamt ngulu itente kinyena, eponee ali litenitere?
#   A. Ichips. Etubio idisdis kakipikini toma  Okiala loka kim loko kuju chut,  paka nam edaunore akipee kijokis,  kakipikin akipii kotauchi.
#   B. Akimaa. Ipikino pwap  aadis adis kuju kakaratasit, kakinyekin  kowokoto kakolong, kosodi kobilibilite, idis dis. ← correct
#   C. Emugati. Itenio kakiria  kipikinete akinyet numwaka, kere konyee kinyekinete kobu.
#   D. Emuchere luwowate kakinyet. Emuchere nuh mema kipoote  epyakion kwapu, kakichikakin kakitoi, kakipore
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✗] Q5 (Swahili) [Image 2 Questions]
#   Question: Chombo cha bluu kilicho kwenye kona ya juu kulia kina vipande vingi vya chakula fulani vilivyokauka na kukatwakatwa. Ni chakula gani kinachotengenezwa kutokana na nyenzo hii, na ni mchakato gani uliotumika kufikia hatua hii?
#   A. Uji. Huwekwa sakafuni katika tabaka nyembamba juu ya kitambaa, huachwa kikauke juani, kisha huvunjwa vipande vidogo. ← correct
#   B. Wali wa kukaanga. Nafaka ambazo hazijapikwa huwekwa mfululizo, husagwa kwa kutumia rola, na kuchemshwa.
#   C. Mkate. Huchanganywa katika unga, huchovya katika mafuta ya kukaangia, kisha huachwa zipumzike hadi zipoe.
#   D. Chipsi. Hukatwa vipande vipande nyembamba, huokwa katika oveni kwa moto mkali hadi unyevunyevu wote utoke, kisha huchovya kwenye maji ili kupoa.
#   Model output:    C
#   Predicted label: C  |  Correct label: A
#
# [✓] Q6 (English) [Image 2 Questions]
#   Question: The preparations and consumption of many of the foods found in markets incorporate spices and seasonings such as cumin, turmeric, coriander, and ginger. This profile of foods reflects which historical trading relationship?
#   A. British citizens introducing Kenyans to baking and roasting.
#   B. Indian railroad workers and merchants settling in East Africa. ← correct
#   C. American settlers bringing over ideas of preservation and recycling.
#   D. Yoruba traders assimilating into Kenyan markets.
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✗] Q6 (Teso) [Image 2 Questions]
#   Question: Eponee likakiten inyamet a luipwaka kosokoni, ipyanikini iboro luipwaka lukakitijijim. Inyamata luh kijokis  itodikiti akapolok kajenaa kegwelet kalii?
#   A. Abunore kitunga kaluko Yoruba toma agwelet kokenya.
#   B. Itunga luka india luitenete ererwe  kiton lukebele luboyete okidee loka Africa ← correct
#   C. Imusuguu  atodikini itung lukoo Kenya akiporee emugatii kakii wowa.
#   D. Itunga luka amerika ayauni ekiponee kes lokaki gwaa  inyamat apak nepolo kakinyogokin akitosom
#   Model output:    C
#   Predicted label: C  |  Correct label: B
#
# [✗] Q6 (Swahili) [Image 2 Questions]
#   Question: Maandalizi na matumizi ya vyakula vingi vinavyopatikana masokoni yanajumuisha viungo na viungo kama vile bizari, manjano, giligilani, na tangawizi. Wasifu huu wa vyakula unaonyesha uhusiano gani wa kihistoria wa kibiashara?
#   A. Wafanyabiashara wa Yoruba wakijiunga na masoko ya Kenya.
#   B. Walowezi wa Marekani wakileta mawazo ya kuhifadhi na kuchakata tena.
#   C. Raia wa Uingereza wakiwafundisha Wakenya kuoka na kuchoma.
#   D. Wafanyakazi wa reli na wafanyabiashara wa India wakiishi Afrika Mashariki. ← correct
#   Model output:    A
#   Predicted label: A  |  Correct label: D
#
# [✓] Q7 (English) [Image 2 Questions]
#   Question: Focusing on the tins in the image, what are they locally called?
#   A. Uzito
#   B. Kipimo
#   C. Nafaka
#   D. Gorogoro ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✓] Q7 (Teso) [Image 2 Questions]
#   Question: Kiteyoo iboro nuejasii aputo ngolii, enyariti inyena?
#   A. Agorogor ← correct
#   B. Iraito
#   C. Alangir
#   D. Lokakitemio
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✓] Q7 (Swahili) [Image 2 Questions]
#   Question: Kwa kuzingatia makopo kwenye picha, yanaitwaje hapa?
#   A. Nafaka
#   B. Gorogoro ← correct
#   C. Kipimo
#   D. Uzito
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✓] Q8 (English) [Image 2 Questions]
#   Question: The metal buckets and containers originally held things such as paint, seeds, and cooking fat. Now what are they used for? What does this demonstrate?
#   A. Making food portable. Demonstrates transportation and mobility.
#   B. Market display and branding. Demonstrates commerce.
#   C. Measurement and storage. Demonstrates recycling and repurposing. ← correct
#   D. Preservation. Demonstrates innovative refrigeration and sustenance.
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q8 (Teso) [Image 2 Questions]
#   Question: Anddot loka chumat katon iboro,  itingito iboro bala  erangi,  ichoko katoni akinyet kedia. Kipokona iboru ngulu itosomayo eponali. Nyena itodikit.
#   A. Akipyakin inyamat kobeikino adakar. Atodikin  akidak inyamat.
#   B. Akisiboi boro. Itodikit achwaa nakitete nakkisiboi iboro.
#   C. Akipima kakigwaa. Itodikini akinyogoo  akitosom iboro. ← correct
#   D. Akitodiar akigiriasha kiboro. Itodikini  egwelet.
#   Model output:    B
#   Predicted label: B  |  Correct label: C
#
# [✗] Q8 (Swahili) [Image 2 Questions]
#   Question: Ndoo na vyombo vya chuma hapo awali vilikuwa na vitu kama vile rangi, mbegu, na mafuta ya kupikia. Sasa vinatumika kwa nini? Hii inaonyesha nini?
#   A. Maonyesho na chapa ya soko. Inaonyesha biashara.
#   B. Vipimo na uhifadhi. Huonyesha kuchakata na kutumia tena. ← correct
#   C. Kutengeneza chakula kinachoweza kubebeka. Huonyesha usafiri na uhamaji.
#   D. Uhifadhi. Huonyesha uhifadhi na uhifadhi wa hali ya juu wa majokofu.
#   Model output:    A
#   Predicted label: A  |  Correct label: B
#
# [✗] Q9 (English) [Image 3 Questions]
#   Question: Why is this structure in the water?
#   A. This structure was built because birds kept flying onto the mainland, resting on people’s homes, and disturbing agricultural work.
#   B. This structure used to be a restaurant a few years ago. Now, all that remains is the original steel structure standing in the water. This is in Lake Victoria and due to rising sea levels, flooding has cut more and more into the local land. ← correct
#   C. The structure acts as a scarecrow. The birds scares away pests from meddling with important fishing areas for fishermen.
#   D. This structure is utilized for capturing fish. The net underneath traps seafood. Unfortunately, the design also attracts birds.
#   Model output:    D
#   Predicted label: D  |  Correct label: B
#
# [✓] Q9 (Teso) [Image 3 Questions]
#   Question: Nyo ejaree ibore eniii akipi?
#   A. Ibore kachan isomae bala Iboro lukarukwor. Ikwenye erukuorete  iboro llukarioko lu ebunete amunakin lukainyok naminyoto.
#   B. Adukio ibore eni kanu aporiat ikweny, amaat, kakiboi kooria kitunga, kakishal asoma nukakor.
#   C. Iboree ngini, itosomao akiiny ikolee. Enetii kopwap ekamii inyamt lukakipii. Aronus konye ekitenio ken enyarautii ikweny.
#   D. Ibore ngini namaa enyemere ikaru idis kau ngina. Kipokona ibore nideuna erait ichumai agwoete akipii. Nuh ejasii anam loka Victoria, atupa kakiyatakin kakipii, elamarosii akipii amaat kitungaa. ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✓] Q9 (Swahili) [Image 3 Questions]
#   Question: Kwa nini muundo huu uko ndani ya maji?
#   A. Jengo hili lilijengwa kwa sababu ndege waliendelea kuruka bara, wakipumzika kwenye nyumba za watu, na kusumbua kazi za kilimo.
#   B. Jengo hili lilikuwa mgahawa miaka michache iliyopita. Sasa, kilichobaki ni jengo la awali la chuma lililokuwa limesimama ndani ya maji. Hili liko katika Ziwa Victoria na kutokana na kupanda kwa kina cha bahari, mafuriko yamezidi kuathiri ardhi ya eneo hilo. ← correct
#   C. Muundo huo hufanya kazi kama kitisho cha kunguru. Ndege hao huwaogopesha wadudu kutokana na kuingilia maeneo muhimu ya uvuvi kwa wavuvi.
#   D. Muundo huu hutumika kukamata samaki. Wavu ulio chini yake hunasa dagaa. Kwa bahati mbaya, muundo huo pia huvutia ndege.
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✗] Q10 (English) [Image 3 Questions]
#   Question: Which species of bird is shown by the black-headed bird with the white body in the top center of the image?
#   A. Cormorant
#   B. Yellow-billed Stork
#   C. Great Egret
#   D. African sacred ibis ← correct
#   Model output:    C
#   Predicted label: C  |  Correct label: D
#
# [✗] Q10 (Teso) [Image 3 Questions]
#   Question: Nyena ataker kikweny nitodikit ikweny nikironon kakou katon akwan  naka kwangan nejii kuju kiding kaputoo ngolii?
#   A. Ekeny lo lo ka akipi lo akirion
#   B. Acuroit ← correct
#   C. Amorocokin na aanywang
#   D. Amorocokin na ejaatar keda eitoli lo eajany
#   Model output:    D
#   Predicted label: D  |  Correct label: B
#
# [✗] Q10 (Swahili) [Image 3 Questions]
#   Question: Ni aina gani ya ndege inayoonyeshwa na ndege mwenye kichwa cheusi mwenye mwili mweupe katikati ya picha?
#   A. Stork mwenye mdomo wa manjano
#   B. Komoranti
#   C. Ibis takatifu za Kiafrika ← correct
#   D. Mchuzi Mkuu
#   Model output:    A
#   Predicted label: A  |  Correct label: C
#
# [✓] Q11 (English) [Image 3 Questions]
#   Question: Which species of birds are all seen in the image?
#   A. Grey Crowned Crane, African Jacana, Sooty Gull, Dwarf Bittern
#   B. African sacred ibis, Great Egret, Yellow-billed Stork, Cormorant ← correct
#   C. Little Grebe, Blacksmith Plover, Whiskered Tern, Hadada Ibis
#   D. White-faced Whistling Duck, Red-knobbed Coot, Hamerkop, Striated Heron
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✗] Q11 (Teso) [Image 3 Questions]
#   Question: Nyena atakere kikweny atakanete kaputo kana?
#
#   A. Ekeny lo lo eduki akipi, Ekeny lo lo egwedi apany, Ekeny lo lo ka akipi lo ejaatar keda ituben, Aruut
#   B. Acuroit, Amorocokin na aanywang, Amorocokin na ejaatar keda eitoli lo eajany, Enyilil ← correct
#   C. Ewalu, Ekeny lo lo ebeleketi amun, Ekeny lo lo ka anam lo ka asirikiny, Amorocokin na edit
#   D. Abanga na aanywang elosikinit kanyen, Ekeny lo lo ka akipi lo ejaatar keda arem na arengan kanyen, Among'ot, Amorocokin na korit
#   Model output:    A
#   Predicted label: A  |  Correct label: B
#
# [✗] Q11 (Swahili) [Image 3 Questions]
#   Question: Ni aina gani za ndege zinazoonekana kwenye picha?
#   A. Kijidudu Kidogo, Mhunzi Plover, Mnyoofu Tern, Hadada Ibis
#   B. Bata Mzungu Mwenye Uso Mweupe, Coot Mwenye Vifundo Vikundu, Hamerkop, Korongo Mwenye Milia
#   C. Korongo Mwenye Taji la Kijivu, Jacana wa Kiafrika, Shakwe Mdogo, Kibete
#   D. Kwani mtakatifu wa Kiafrika, Mchuzi Mkuu, Korongo mwenye mdomo wa manjano, Cormorant ← correct
#   Model output:    B
#   Predicted label: B  |  Correct label: D
#
# [✓] Q12 (English) [Image 4 Questions]
#   Question: What is the most common use of the boats shown in the foreground?
#   A. Fishing ← correct
#   B. Leisure
#   C. Transporting goods
#   D. Sea travel
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✓] Q12 (Teso) [Image 4 Questions]
#   Question: Ateter neetodunii aputoo nah , inyena chede nesikitsomate tunga
#   A. Akitolosia Iboro
#   B. Akilosia Akaaree nakapolon
#   C. Akiiny ← correct
#   D. Aboyikini
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q12 (Swahili) [Image 4 Questions]
#   Question: Ni matumizi gani ya kawaida ya boti zinazoonyeshwa mbele?
#   A. Usafiri wa baharini
#   B. Burudani
#   C. Kusafirisha bidhaa
#   D. Uvuvi ← correct
#   Model output:    A
#   Predicted label: A  |  Correct label: D
#
# [✓] Q13 (English) [Image 4 Questions]
#   Question: What body of water is being shown in the background?
#   A. The Great Lakes
#   B. Lake Victoria ← correct
#   C. The Indian Ocean
#   D. The Red Sea
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✓] Q13 (Teso) [Image 4 Questions]
#   Question: Akipii nuh, luetodunii enyariti nyena.
#   A. Akare loka Hindi
#   B. Anam nakapolon
#   C. Anam napoleon lokared
#   D. Anam loka Victoria ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q13 (Swahili) [Image 4 Questions]
#   Question: Ni maji gani yanayoonyeshwa chinichini?
#   A. Maziwa Makuu
#   B. Ziwa Victoria ← correct
#   C. Bahari ya Hindi
#   D. Bahari Nyekundu
#   Model output:    C
#   Predicted label: C  |  Correct label: B
#
# [✓] Q14 (English) [Image 4 Questions]
#   Question: The woman in the front left is wearing a traditional Kenyan cloth. What is it called?
#   A. Amauti
#   B. Agbada
#   C. Kitenge ← correct
#   D. Kente
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✓] Q14 (Teso) [Image 4 Questions]
#   Question: Aberu nigwoii, Kingaren kokedweny, enapit enaga lokagogong loka kenya. Enyariti enaga ngolii nyena?
#   A. Amauti
#   B. Kente
#   C. Kitenge ← correct
#   D. Agbada
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✓] Q14 (Swahili) [Image 4 Questions]
#   Question: Mwanamke aliye mbele kushoto amevaa kitambaa cha kitamaduni cha Kenya. Kinaitwaje?
#   A. Kitenge ← correct
#   B. Amauti
#   C. Kente
#   D. Agbada
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✓] Q15 (English) [Image 4 Questions]
#   Question: Based on the text that can be found on the boats, where in Kenya is this photo taken?
#   A. Dunga Beach ← correct
#   B. Kit-Mikayi
#   C. Impala Sanctuary
#   D. Hippo Point
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✗] Q15 (Teso) [Image 4 Questions]
#   Question: Kianyuyo agirit nejii ateter nejii aputoo ngolii, aputa nah keyaroo nama walii akwap loka Kenya?
#   A. Hippo Point
#   B. Dunga Beach ← correct
#   C. Impala Sanctuary
#   D. Kit-Mikayi
#   Model output:    D
#   Predicted label: D  |  Correct label: B
#
# [✓] Q15 (Swahili) [Image 4 Questions]
#   Question: Kulingana na maandishi yanayopatikana kwenye boti hizo, picha hii imepigwa wapi Kenya?
#   A. Ufuo wa Dunga ← correct
#   B. Kit-Mikayi
#   C. Kiboko Point
#   D. Hifadhi ya Impala
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✓] Q16 (English) [Image 5 Questions]
#   Question: How has M-PESA primarily transformed financial inclusion in Kenya?
#   A. It has completely turned Kenya’s financial inclusion upside down, as it has led to mass inflation as a result of more cash being able to flow into and out of businesses.
#   B. It has made little to no difference, as most people don’t see a practical use for it.
#   C. It has made the financial landscape of Kenya more exclusionary, as it is only offered to specific groups of people.
#   D. It has revolutionized Kenya’s financial inclusion as it allows people without bank accounts to securely deposit, withdraw, send, and receive money directly from their mobile phones. ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✓] Q16 (Teso) [Image 5 Questions]
#   Question: Ikoni asoma ka mpessa ibelekini akijara kangotelei kokenya aii?
#   A. Edeuni aosma ken agelakina noi kanuu itsosomatete tunga liye ettiyakuna bon.
#
#   B. Elonyaki eponee lokapeseii kokenya, Kanuu alachakii lumemmu kejasi kakaunt  abeikini  akigwaa, akiyakani,  kaki diyauni abolai alomuni kasiimu ← correct
#   C. Ebelok chut akiro kapesei kokenya kuju pwap, edipo apesei edachari pwap, nuh ebunete atupa kapesei akilom kalomar kogwelet.
#   D. Ayawu etanikina nedit, kanuu itete tunga luipwaka  kiteete adumunet kasoma ken
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✓] Q16 (Swahili) [Image 5 Questions]
#   Question: M-PESA imebadilisha vipi kimsingi ujumuishaji wa kifedha nchini Kenya?
#   A. Haijaleta tofauti kubwa au hakuna tofauti yoyote, kwani watu wengi hawaoni matumizi yake ya vitendo.
#   B. Imefanya mazingira ya kifedha ya Kenya kuwa ya ubaguzi zaidi, kwani hutolewa kwa makundi maalum ya watu pekee.
#   C. Imebadilisha kabisa ujumuishaji wa kifedha wa Kenya, kwani imesababisha mfumuko mkubwa wa bei kutokana na pesa nyingi zinazoweza kuingia na kutoka katika biashara.
#   D. Imebadilisha ujumuishaji wa kifedha wa Kenya kwani inaruhusu watu wasio na akaunti za benki kuweka, kutoa, kutuma, na kupokea pesa moja kwa moja kutoka kwa simu zao za mkononi kwa usalama. ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q17 (English) [Image 5 Questions]
#   Question: What are these local vendor stalls locally called?
#   A. Kiosks ← correct
#   B. Concessions
#   C. Booths
#   D. Newsstands
#   Model output:    C
#   Predicted label: C  |  Correct label: A
#
# [✓] Q17 (Teso) [Image 5 Questions]
#   Question: Nyena ekiror enyarite itogoi luchis luke bele nguluu kaduket?
#   A. Abutii
#   B. Agwoete nakakirabaraba
#   C. Eduka lochii.
#   D. Kiosks ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q17 (Swahili) [Image 5 Questions]
#   Question: Vibanda hivi vya wauzaji wa ndani vinaitwaje?
#   A. Vibanda ← correct
#   B. Mapunguzo
#   C. Vibanda ← correct
#   D. Vibanda vya magazeti
#   Model output:    D
#   Predicted label: D  |  Correct label: A
#
# [✓] Q18 (English) [Image 5 Questions]
#   Question: What is the significance of Coca-Cola being branded on the structure and in Kenya as a whole?
#   A. Coca-Cola sponsors local businesses and has incentives that pay people to openly wear, paint, and display their products. This has heavily stimulated the local markets but serves as a stark reminder that companies are slowly overtaking everyday life in Kenya.
#   B. Coca-Cola has bought out all local markets in Kenya to create a monopoly over the soda market. They are advertising themselves on the structure to subconsciously make citizens want to buy their products more often.
#   C. There is no significance behind the logo being painted; citizens around Kenya show love towards brands they love by painting them on their houses, cars, and businesses.
#   D. Coca-Cola is the continent's largest bottler, with a bottling plant right in Kisumu. Coca-Cola provides stall owners with free or subsidized branded equipment like refrigerators, umbrellas, and painted storefronts. In exchange, the stall owners agree to stock Coca-Cola products and prominently display the logo. ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q18 (Teso) [Image 5 Questions]
#   Question: Nyena adumnute  ka cocacola ajaut kakigirashia Kotogo kangoli, katoni apwap nako Kenya kere.
#
#   A. Agwel cocala esokoni kisodai kijokis eteter erauni nesii loke bele kaniko kuju. Itodoarito  ebele kesi kotogoi kangulu teter itunga  egwelete iboro kes.
#
#   B. Emam adumunet kalama kangin, itung aloka keya elakarkina akipyakin alama ngini otogoi, amotokai kes kiton agwelet kes kalong
#
#   C. Ekampuni loka cocacal nesi le polo apwap  loka africa, ejasi kebele  lokapolon Kisumu. Ainakit ituga iboro luka long, bala elilinya, kakilony  echamuto itunga  egwelanar esoda kes, kakitodiar alama kes. ← correct
#   D. Cocacola itopoloi ebele kesii koponee kaloka gwelakini itunga inagai, kakigir otogoi kes, kakitodiar iboro keso. Kakikono neni etopolo ebele loka kenya, itodikit ikampunio  epoloyete  atipet toma Okenya
#
#   Model output:    D
#   Predicted label: D  |  Correct label: C
#
# [✗] Q18 (Swahili) [Image 5 Questions]
#   Question: Je, kuna umuhimu gani wa Coca-Cola kuwekewa chapa kwenye muundo huo na nchini Kenya kwa ujumla?
#   A. Coca-Cola imenunua masoko yote ya ndani nchini Kenya ili kuunda ukiritimba juu ya soko la soda. Wanajitangaza wenyewe kwenye muundo huo ili kuwafanya raia watake kununua bidhaa zao mara nyingi zaidi.
#   B. Hakuna umuhimu wowote nyuma ya nembo hiyo kuchorwa; raia kote Kenya huonyesha upendo kwa chapa wanazozipenda kwa kuzichora kwenye nyumba zao, magari, na biashara zao.
#   C. Coca-Cola inafadhili biashara za ndani na ina motisha zinazowalipa watu kuvaa, kupaka rangi, na kuonyesha bidhaa zao hadharani. Hii imechochea sana masoko ya ndani lakini inatumika kama ukumbusho dhahiri kwamba makampuni yanazidi polepole maisha ya kila siku nchini Kenya.
#   D. Coca-Cola ndiyo kiwanda kikubwa zaidi cha chupa barani Afrika, kikiwa na kiwanda cha kuwekea chupa huko Kisumu. Coca-Cola huwapa wamiliki wa vibanda vifaa vya bure au vya ruzuku kama vile jokofu, miavuli, na maduka yaliyopakwa rangi. Kwa kubadilishana, wamiliki wa vibanda hukubali kuhifadhi bidhaa za Coca-Cola na kuonyesha nembo hiyo waziwazi. ← correct
#   Model output:    C
#   Predicted label: C  |  Correct label: D
#
# [✓] Q19 (English) [Image 5 Questions]
#   Question: What action is most likely to take place at a structure like this?
#   A. Setting up transportation to a place.
#   B. Selling old clothes for cash.
#   C. Submit tax forms and documents.
#   D. Buying small produce and food. ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q19 (Teso) [Image 5 Questions]
#   Question: Nyena ibore nebeikini akisomakini kariri ketogo nejii aputo na?
#
#   A. Agwele  iboro idis kinyamen ← correct
#   B. Agwelanar inagai lumojong
#
#   C. Akipikin epone lokalosia namiche
#   D. Ainakin  emusolo katoni apaplai
#   Model output:    C
#   Predicted label: C  |  Correct label: A
#
# [✗] Q19 (Swahili) [Image 5 Questions]
#   Question: Ni hatua gani inayowezekana zaidi kufanyika katika jengo kama hili?
#   A. Kuweka usafiri hadi mahali.
#   B. Kununua mazao madogo na chakula. ← correct
#   C. Kuuza nguo za zamani kwa pesa taslimu.
#   D. Wasilisha fomu na hati za kodi.
#   Model output:    C
#   Predicted label: C  |  Correct label: B
#
# [✗] Q20 (English) [Image 6 Questions]
#   Question: What rocks are shown in this image, and what is their significance?
#   A. Quarry stones from nearby mines. They are shaped because its raw state is often unusable. Frequently used for moisture resistance and underground construction
#   B. Limestone found from the shallow parts of Lake Victoria. Its softer texture makes it central to construction and agriculture. It is used for treating wastewater and fills in for food and toothpaste.
#   C. Granite stones used for construction. Because granite is dense and durable, the pictured stones are used for heavy-duty construction and flooring.
#   D. Calcium Stones from Kodiaga. These stones are traditionally consumed by pregnant women to supplement calcium, supporting bone health for both mother and child. ← correct
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: D
#
# [✗] Q20 (Teso) [Image 6 Questions]
#   Question: Nyena amoru nuitodute kaputo kana na nyena adumunte kes?
#   A. Amoru neelemute  kama ebokere emaram. Ekepite kanu emamm ketapana akitosom kesii kasodit. Duchu itosomao kanu emasiete akipii na adukio nuko pwap.
#   B. Amoru  nuka laim, nue dummuno kotolima loka anam naka Victoria. Enonok naesi edipori itosomao kakoru kitoni akiduk. Itosomao akimada akipii kakitene ekeya kikyela.
#   C. Amoru nuka granait  nuitosomao aduko. Kanu alangiri egranait kibote de ding itosomao kesii aduko.
#   D. Amoru nuka kalshiam nuko Kodiaga. Amoru nuh kakijara kanaka sem, anyemete aberu nepotiete  akiyatakini akwana kes ekalshiam, kanuka kingarakin akoyo kikoku katoken. ← correct
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: D
#
# [✗] Q20 (Swahili) [Image 6 Questions]
#   Question: Ni miamba gani inayoonyeshwa kwenye picha hii, na umuhimu wake ni upi?
#   A. Chokaa inayopatikana kutoka sehemu zisizo na kina kirefu za Ziwa Victoria. Umbile lake laini hulifanya kuwa muhimu kwa ujenzi na kilimo. Inatumika kwa ajili ya kutibu maji machafu na kujaza chakula na dawa ya meno.
#   B. Mawe ya granite yanayotumika kwa ajili ya ujenzi. Kwa sababu granite ni nzito na hudumu, mawe yaliyoonyeshwa kwenye picha hutumika kwa ajili ya ujenzi wa kazi nzito na sakafu.
#   C. Mawe ya Kalsiamu kutoka Kodiaga. Mawe haya huliwa kijadi na wanawake wajawazito ili kuongeza kalsiamu, na kusaidia afya ya mifupa kwa mama na mtoto. ← correct
#   D. Mawe ya machimbo kutoka migodi iliyo karibu. Yameumbwa kwa sababu hali yake mbichi mara nyingi haitumiki. Hutumika mara kwa mara kwa ajili ya upinzani wa unyevu na ujenzi wa chini ya ardhi
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: C
#
# [✗] Q21 (English) [Image 6 Questions]
#   Question: What are the red balls in plastic and how were they prepared for the market?
#   A. Kidney beans. They are sorted and soaked. They are boiled for 10 minutes to denature the toxins. Eventually, the heat is reduced to a gentle simmer for under an hour until they are tender.
#   B. Groundnuts. They are prepped, soaked with hot water, and stirred and cooked over a heated pan. After this, the skin darkens and peels. They are cooled and they get crispy. ← correct
#   C. Groundnuts. They are prepped and peeled. The water in a pot is seasoned as it is being boiled. When the water is boiled, the groundnuts are poured in and cooked for around three hours. After, they are soaked for a few hours so the salt penetrates the shell. They are drained and sold.
#   D. Macadamia nuts. They are dehusked then the shells are cracked. They are dry roasted on a baking sheet for 10-12 minutes. During this process, they can be seasoned. They are stored and sold.
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: B
#
# [✗] Q21 (Teso) [Image 6 Questions]
#   Question: Nyena imoru luchusi lukaringak nwejasii okartasi, kosodi itenio kesii eponali?
#   A. Amarage kepiro. Esekio kakitabaun kakipii.  Itukulauno kakipi idaikan itomon kanuka lemar adwarus. Kitolosi akiporee bala asaa epee kakim kadiosii kononokar
#   B. Amaide loka Macadamia. Epacho kaki pietar. Epeyoo kakim koaikan bala itomon karee. Apakii kanaa ipikino  abalang  kakipyakin ochwei, kagwelar.
#   C. Emaide. Iwawo kakim nejasii kabalang, kowokoto. ← correct
#   D. Emaide. Epacho emaido. Akipii nujeasii amot nwemaka , etayatakino iboro lukajijim, kokulaete. Etolosit emadie akulau isaanii iuni, kedaunosii, utabauno isaan idisi, kolom abalang tenaa. Elemare akipii kijokis kagwelar.
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: C
#
# [✗] Q21 (Swahili) [Image 6 Questions]
#   Question: Mipira nyekundu iliyotengenezwa kwa plastiki ni nini na iliandaliwaje kwa ajili ya soko?
#   A. Maharage ya figo. Yamepangwa na kulowekwa. Yanachemshwa kwa dakika 10 ili kuondoa sumu. Hatimaye, moto hupunguzwa hadi kupikwa kidogo kwa chini ya saa moja hadi yawe laini.
#   B. Karanga. Hutayarishwa na kung'olewa. Maji kwenye sufuria hutiwa viungo yanapochemshwa. Maji yanapochemshwa, karanga hutiwa ndani na kupikwa kwa takriban saa tatu. Baada ya hapo, huloweshwa kwa saa chache ili chumvi iingie kwenye ganda. Huondolewa na kuuzwa.
#   C. Kokwa za makadamia. Huondolewa maganda kisha maganda hupasuka. Hukaushwa na kuokwa kwenye karatasi ya kuokea kwa dakika 10-12. Wakati wa mchakato huu, zinaweza kutiwa viungo. Huhifadhiwa na kuuzwa.
#   D. Karanga. Hutayarishwa, huloweshwa na maji ya moto, na kukorogwa na kupikwa kwenye sufuria yenye moto. Baada ya haya, ngozi hutiwa giza na kuchubuka. Hupozwa na kung'oka. ← correct
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: D
#
# [✗] Q22 (English) [Image 6 Questions]
#   Question: What is in the white bucket?
#   A. Commercially-produced blue stones
#   B. KSL Tropical Mints ← correct
#   C. Glass marbles
#   D. Tanzanite gems
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: B
#
# [✗] Q22 (Teso) [Image 6 Questions]
#   Question: Nyena ejii andoot naka kwangan?
#   A. Amoru nuka Tanzania
#   B. Amoru nuitente nuka gwelanar.
#   C. Amoru luka glass
#   D. Imints loka KSL ← correct
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: D
#
# [✗] Q22 (Swahili) [Image 6 Questions]
#   Question: Ni nini kilichomo kwenye ndoo nyeupe?
#   A. Marumaru za kioo
#   B. Mawe ya bluu yanayotengenezwa kibiashara
#   C. Vito vya Tanzanite
#   D. KSL Mints za Tropiki ← correct
#   Model output:    ERROR
#   Predicted label: None  |  Correct label: D
#
# [✓] Q23 (English) [Image 7 Questions]
#   Question: What attire is being worn in this image?
#   A. Liku
#   B. Hula kahiko skirts
#   C. Owali sisal skirts ← correct
#   D. Piupiu skirts
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q23 (Teso) [Image 7 Questions]
#   Question: Nyena iboro enapite kaputo kanaa?
#   A. Asikat naka amujaj loka Owalii ← correct
#   B. Asikat naka Hula kahiko
#   C. Liku
#   D. Asikat luka piupiu
#   Model output:    D
#   Predicted label: D  |  Correct label: A
#
# [✗] Q23 (Swahili) [Image 7 Questions]
#   Question: Ni mavazi gani yanayovaliwa katika picha hii?
#   A. Sketi za Hula kahiko
#   B. Sketi za katani za Owali ← correct
#   C. Liku
#   D. Sketi za Piupiu
#   Model output:    D
#   Predicted label: D  |  Correct label: B
#
# [✗] Q24 (English) [Image 7 Questions]
#   Question: What community is this attire representative of?
#   A. Somali
#   B. Meru
#   C. Maasai
#   D. Luo ← correct
#   Model output:    C
#   Predicted label: C  |  Correct label: D
#
# [✓] Q24 (Teso) [Image 7 Questions]
#   Question: Nyena atakere eboikit anapa loka ibor kaluu?
#   A. Dholuo ← correct
#   B. Imeeru
#   C. Isomalii
#   D. Imaasai
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✗] Q24 (Swahili) [Image 7 Questions]
#   Question: Mavazi haya yanawakilisha jamii gani?
#   A. Kisomali
#   B. Meru
#   C. Kiluo ← correct
#   D. Wamasai
#   Model output:    A
#   Predicted label: A  |  Correct label: C
#
# [✓] Q25 (English) [Image 7 Questions]
#   Question: When and for what is this attire traditionally worn?
#   A. By children and used for dancing. It is primarily worn at children's birthday parties and celebrates the freedom of youth and celebration of life. Children dance in circles and play the nyatiti and abu
#   B. By women and men and used for rituals. It is primarily worn during sacred moments for religion and coming of age. The community believes its material represents the creations of the Divine, and is thus holy attire.
#   C. By women and used for dancing. It is primarily worn during marriage ceremonies, celebrating newborns, and initiations. The loose fibers allow for free movement and for the skirt to sway and flow to the music. ← correct
#   D. By women and used for fashion. It is primarily worn to show off the vibrant colors visible such as bright pink, purple, and teal. The stripping, softening, and dying fibers from the sisal plant make it very beautiful and this fine craftsmanship makes it an attire worn for fashionable and flashy purposes.
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q25 (Teso) [Image 7 Questions]
#   Question: Worii kapaki kanii enapere iboroo iluu
#   A. Itosomate idwee akilejia, aoaki nakaki numunumu akidounio, katoni apak nakakitubio kaluka tumunak.
#   B. Enapete aberu  ki kiliyok  esaa lokakinumnum. Itosomao apakii nakakinumnum iboro lukedeke katoni akinumnum amojong. Emunt ateker amuja egwoikit akiro kedeke, na eraiti akinap.
#   C. Enapete aberu  ileete. Enapio apakii nakaki numnum emanyit, kakidowuni ikoku. Anunuk  kamujajua elachankini itwanu akilej. ← correct
#   D. Enapete aberu  kanukaminakes bon. Itosomao akitoduni irangino. Akitene ne jokuna nah idiport enapite iboro luh akitodiar amina kitunga kalakara.
#   Model output:    B
#   Predicted label: B  |  Correct label: C
#
# [✗] Q25 (Swahili) [Image 7 Questions]
#   Question: Mavazi haya huvaliwa lini na kwa ajili ya nini?
#   A. Na wanawake na hutumika kwa densi. Huvaliwa hasa wakati wa sherehe za ndoa, kusherehekea watoto wachanga, na unyago. Nyuzi hizo huru huruhusu harakati huru na sketi kutikisika na kutiririka kwa muziki. ← correct
#   B. Na wanawake na wanaume na hutumika kwa ajili ya ibada. Huvaliwa hasa wakati wa nyakati takatifu kwa ajili ya dini na kukomaa. Jamii inaamini kwamba nyenzo zake zinawakilisha uumbaji wa Mungu, na hivyo ni mavazi matakatifu.
#   C. Na wanawake na hutumika kwa mitindo. Huvaliwa hasa kuonyesha rangi angavu zinazoonekana kama vile waridi angavu, zambarau, na bluu. Nyuzi zinazong'aa, zinazolainisha, na zinazokufa kutoka kwa mmea wa katani huifanya iwe nzuri sana na ufundi huu mzuri huifanya iwe vazi linalovaliwa kwa madhumuni ya mtindo na ya kuvutia.
#   D. Na watoto na hutumika kwa densi. Huvaliwa hasa kwenye sherehe za kuzaliwa kwa watoto na husherehekea uhuru wa ujana na sherehe ya maisha. Watoto hucheza kwenye miduara na hucheza nyatiti na abu
#   Model output:    C
#   Predicted label: C  |  Correct label: A
#
# [✓] Q26 (English) [Image 8 Questions]
#   Question: What are the items held in the black tape or band?
#   A. Natural luffa sponges ← correct
#   B. Sea sponges
#   C. White maize
#   D. Dried plantains
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✗] Q26 (Teso) [Image 8 Questions]
#   Question: Nyena ibor eruchokite kaunot kanakiryonon
#   A. Echangwe loka anam nakapolon
#   B. Echangwee Lokekitoi. ← correct
#   C. Ekuridi lokekwangan
#   D. Alaboro nukawoko.
#   Model output:    A
#   Predicted label: A  |  Correct label: B
#
# [✓] Q26 (Swahili) [Image 8 Questions]
#   Question: Ni vitu gani vilivyowekwa kwenye mkanda mweusi au utepe?
#   A. Mahindi meupe
#   B. Ndizi zilizokaushwa
#   C. Sifongo za asili za luffa ← correct
#   D. Sifongo za baharini
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q27 (English) [Image 8 Questions]
#   Question: What is the purpose of the items held in the black tape or band?
#   A. Their natural liquid. They hold natural liquids that are mineral-rich and upon harvest are drained for these liquids. They are set out until all the liquid from the body is collected.
#   B. Construction. They are torn apart and mixed with cement to fill in gaps in walls, floors, and roofs. It’s flexible and strong material makes it perfect for long-lasting structure enhancements and fixes.
#   C. Consumption. It provides great nutrients such as potassium and vitamin B6. Eating them contributes to better gut health and thus acts as a healthy source of food for locals.
#   D. Body scrubbers. It is soaked in water and then they are perfect for exfoliation in the shower. They are also biodegradable and natural tools for scrubbing dishes and countertops. ← correct
#   Model output:    A
#   Predicted label: A  |  Correct label: D
#
# [✗] Q27 (Teso) [Image 8 Questions]
#   Question: Nyena atenikina kiboro erucjokite kaunot kankiryonon
#   A. Akipii kes nwe tapana adumum. Itingito akipii nejasii kiminerals, edwenyo  elemunete akipii ngulu. Ejasii kosodii nelemenere akipii kijokis kakwan.
#   B. Akiduk. Echilaro kokiding akinyalakin kesimit akilelebia aduyoka otogoi katoni kuju ketogo.  Anonnok kes idiporit itosomao adukia itogoi lu iboyete
#   C. Echangwe Lokakiswaga akwan. Itabuono kakipi, Eboste tenan kalipo, katoni  iboro luiswagere ibor luenyamere. ← correct
#   D. Luinyamat. Einakini iboro luedikte akwan  bala Potassium katoni Vitamin B6. Akinyam iboro ngulu einakini akok nejokuna, kosodi isomae bala inyamen nuelae kakwan.
#   Model output:    D
#   Predicted label: D  |  Correct label: C
#
# [✗] Q27 (Swahili) [Image 8 Questions]
#   Question: Madhumuni ya vitu vilivyoshikiliwa kwenye utepe mweusi au bendi ni nini?
#   A. Visafishaji vya mwili. Vinaloweshwa kwenye maji na kisha vinafaa kwa ajili ya kusugua ngozi wakati wa kuoga. Pia ni vifaa vinavyooza na vya asili vya kusugua vyombo na kaunta. ← correct
#   B. Matumizi. Hutoa virutubisho bora kama vile potasiamu na vitamini B6. Kula hivyo huchangia afya bora ya utumbo na hivyo hufanya kazi kama chanzo bora cha chakula kwa wenyeji.
#   C. Kimiminika chao cha asili. Huhifadhi vimiminika vya asili vyenye madini mengi na wakati wa mavuno huchujwa kwa ajili ya vimiminika hivi. Huwekwa nje hadi vimiminika vyote kutoka mwilini vitakapokusanywa.
#   D. Ujenzi. Hupasuka na kuchanganywa na saruji ili kujaza mapengo kwenye kuta, sakafu, na paa. Ni nyenzo inayonyumbulika na imara inayoifanya iwe bora kwa ajili ya uboreshaji na marekebisho ya muundo wa kudumu kwa muda mrefu.
#   Model output:    C
#   Predicted label: C  |  Correct label: A
#
# [✗] Q28 (English) [Image 8 Questions]
#   Question: What is the stack and on the right and what are the items used for?
#   A. Mukeu, which is harvested to make strong, durable natural ropes. It is also used to weave baskets and traditional kiondo bags
#   B. Stacks of locally made rubber bands. helpful for bundling to hold and bind products locally sold together. Also used for crafting, orthodontics, and transport.
#   C. Raw jute fiber, which is utilized to make fabrics, bags, and mats. It can also be turned into yarn for weaving. ← correct
#   D. Dried banana leaves. They have multiple uses, including being ground up for tea. They are also used to wrap up spices and small foods for preservation and and braided into ingata, which is used when carrying heavy things
#   Model output:    A
#   Predicted label: A  |  Correct label: C
#
# [✗] Q28 (Teso) [Image 8 Questions]
#   Question: Nyena iboro nu itogwoete nateten nyena asom kiboro kangulu?
#
#   A. Akwi nuka amuka na anyorire. Ejaatar keda aswamisinei ipu, naitisai aponia aitagulaun ecae lo amugit. Esubio bobo amunokin iasama keda aanyam na ititini aitogogong, keda aodokin arebeit (ingata) na ebeit aitit keda aiki iboro lu ititini.
#   B. Anya nuka akorobos lu emameun apasao, lu eswamao nuka amunokin imanyas, ijokin, keda itatago. Ipedori bobo aenit keda airiit ecae nuka aodokin. ← correct
#   C. Mukeu, lo aponia eeswamao aoroi na agogong ka na itatene. Esubio bobo aodokin itatago keda itatago nuka kiondo.
#   D. Itatago nuka apira nuka amukian aswam kotoma ateker. Konyout amunokin keda aitogogong keda amonikin emisago nuka amukian adukanat nepepe. Esubio bobo aitopol, acuran, keda aiki kwan.
#   Model output:    A
#   Predicted label: A  |  Correct label: B
#
# [✓] Q28 (Swahili) [Image 8 Questions]
#   Question: Mrundiko ni nini na upande wa kulia ni nini na vitu hivyo vinatumika kwa ajili ya nini?
#   A. Majani ya ndizi yaliyokaushwa. Yana matumizi mengi, ikiwa ni pamoja na kusagwa kwa ajili ya chai. Pia hutumika kufunga viungo na vyakula vidogo kwa ajili ya kuhifadhi na kusokotwa kwenye ingata, ambayo hutumika wakati wa kubeba vitu vizito.
#   B. Mukeu, ambayo huvunwa ili kutengeneza kamba za asili zenye nguvu na za kudumu. Pia hutumika kusuka vikapu na mifuko ya kitamaduni ya kiondo
#   C. Nyuzi mbichi za jute, ambazo hutumika kutengeneza vitambaa, mifuko, na mikeka. Pia zinaweza kubadilishwa kuwa uzi wa kufuma. ← correct
#   D. Mirundiko ya mikanda ya mpira iliyotengenezwa kienyeji. Inasaidia kwa kushikilia na kufunga bidhaa zinazouzwa kienyeji pamoja. Pia hutumika kwa ufundi, orthodontics, na usafiri.
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q29 (English) [Image 9 Questions]
#   Question: What type of fish is pictured?
#   A. Haplochromines (Fulu)
#   B. Lake Magadi Tilapia (Oreochromis alcalicus)
#   C. Omena (Silver Cyprinid) ← correct
#   D. Tilapia (Ngege)
#   Model output:    D
#   Predicted label: D  |  Correct label: C
#
# [✗] Q29 (Teso) [Image 9 Questions]
#   Question: Ani kanyara na ka igwenya na itodunitai kotoma epicha?
#   A. Ngege ka anam lo Magadi Oreochromis alcalicus
#   B. Ngege keda ewape
#   C. Fulu keda amuny
#   D. Omena keda emukene ← correct
#   Model output:    A
#   Predicted label: A  |  Correct label: D
#
# [✓] Q29 (Swahili) [Image 9 Questions]
#   Question: Ni aina gani ya samaki inayoonyeshwa kwenye picha?
#   A. Tilapia (Ngege)
#   B. Haplokromini (Fulu)
#   C. Omena (Siprinidi ya Fedha) ← correct
#   D. Ziwa Magadi Tilapia (Oreochromis alcalicus)
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✓] Q30 (English) [Image 9 Questions]
#   Question: What will this fish be used for after being sold?
#   A. Sole cure for specific diseases
#   B. Food for humans and livestock feed ← correct
#   C. Crushed up to be sold in local drinks
#   D. Bait for game
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✗] Q30 (Teso) [Image 9 Questions]
#   Question: Ani aswam na ka igwenya na akaulo nuka amukit aijany?
#   A. Aitingis kede aiita itingisin nuka amukian apasao
#   B. Aitabul keda amugit ecae lo amukian adukanat
#   C. Aanyam nuka itunga keda aanyam nuka itisai ka ore ← correct
#   D. Aanyam aitogogong aitit igwenya nuka amina
#   Model output:    D
#   Predicted label: D  |  Correct label: C
#
# [✗] Q30 (Swahili) [Image 9 Questions]
#   Question: Samaki huyu atatumika kwa nini baada ya kuuzwa?
#   A. Chambo cha mchezo
#   B. Tiba pekee kwa magonjwa maalum
# ...
#   B. Visiting guests
#   C. The children
#   D. The husband
#   Model output:    D
#   Predicted label: D  |  Correct label: A
#
# [✗] Q35 (Teso) [Image 10 Questions]
#   Question: Inai eboie kotogo lo eponi lo ka ekaulo apol?
#   A. Aberu na nasodit ← correct
#   B. Okilen
#   C. Imongin lukaditot
#   D. Ipejon lu aponia bwan
#   Model output:    C
#   Predicted label: C  |  Correct label: A
#
# [✗] Q35 (Swahili) [Image 10 Questions]
#   Question: Nani anaishi katika kibanda kikubwa zaidi?
#   A. Mume
#   B. Mke wa kwanza ← correct
#   C. Wageni wanaotembelea
#   D. Watoto
#   Model output:    C
#   Predicted label: C  |  Correct label: B
#
# [✓] Q36 (English) [Image 10 Questions]
#   Question: Where was this image likely taken?
#   A. Near the Kenyan Coastal Region
#   B. Near Maasai Mara
#   C. Near Mt. Kenya
#   D. Near Kit Mikayi ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q36 (Teso) [Image 10 Questions]
#   Question: Ani akwap na aponia itelekunai epicha lo?
#   A. Diat Kit Mikayi ← correct
#   B. Diat Mt. Kenya
#   C. Diat anam lo ka akwap na a Kenya lo katenait kidama
#   D. Diat Maasai Mara
#   Model output:    C
#   Predicted label: C  |  Correct label: A
#
# [✗] Q36 (Swahili) [Image 10 Questions]
#   Question: Huenda picha hii ilipigwa wapi?
#   A. Karibu na Maasai Mara
#   B. Karibu na Mkoa wa Pwani wa Kenya
#   C. Karibu na Kit Mikayi ← correct
#   D. Karibu na Mlima Kenya
#   Model output:    B
#   Predicted label: B  |  Correct label: C
#
# [✗] Q37 (English) [Image 10 Questions]
#   Question: What type of Kenyan hut does this image depict?
#   A. Od Mikayi ← correct
#   B. The Manyatta / Enkaji
#   C. The Borana / Rendille Domes
#   D. Swahili Coral Huts
#   Model output:    B
#   Predicted label: B  |  Correct label: A
#
# [✗] Q37 (Teso) [Image 10 Questions]
#   Question: Ani amaduli na ka a Kenya na itodunitai kotoma epicha?
#   A. Od Mikayi ← correct
#   B. Manyatta / Enkaji
#   C. Borana / Rendille Domes
#   D. Itogoi nuka Swahili Coral Huts
#   Model output:    B
#   Predicted label: B  |  Correct label: A
#
# [✗] Q37 (Swahili) [Image 10 Questions]
#   Question: Picha hii inaonyesha aina gani ya kibanda cha Kenya?
#   A. Od Mikayi ← correct
#   B. Mabawa ya Borana / Rendille
#   C. Vibanda vya Matumbawe vya Kiswahili
#   D. Manyatta / Enkaji
#   Model output:    D
#   Predicted label: D  |  Correct label: A
#
# [✓] Q38 (English) [Image 11 Questions]
#   Question: Who’s clothes are seen on the lines?
#   A. Just women’s clothes
#   B. Just men’s clothes
#   C. Just baby clothes
#   D. A family of multiple ages ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q38 (Teso) [Image 11 Questions]
#   Question: Ani iasama lu eanywunitai kidama ka aoroi?
#   A. Lu ka imongin bon
#   B. Lu ka imongin lukaditot bon
#   C. Lu ka iaberu bon
#   D. Lu ka ateker kere ka iisuben lu kapuaka ← correct
#   Model output:    C
#   Predicted label: C  |  Correct label: D
#
# [✗] Q38 (Swahili) [Image 11 Questions]
#   Question: Nguo za nani zinaonekana kwenye mstari?
#   A. Nguo za wanawake pekee
#   B. Nguo za watoto tu
#   C. Familia ya umri mbalimbali ← correct
#   D. Nguo za wanaume pekee
#   Model output:    B
#   Predicted label: B  |  Correct label: C
#
# [✓] Q39 (English) [Image 11 Questions]
#   Question: What does this image say about the locals' treatment of clothes?
#   A. They collect clothes and often sell it for income
#   B. They use washing and drying machines
#   C. They sew their own clothes
#   D. They handwash it and hang it out on a clothesline ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✓] Q39 (Teso) [Image 11 Questions]
#   Question: Ani itodunit epicha lo kotoma aswam na ka itunga ka ore keda iasama?
#   A. Erodit iasama kwan iaswama nuka akanin
#   B. Emait iasama keda iaswamak lu ka ailwat keda aitwan
#   C. Elwatar keda akanin ka aenit kidama ka aoroi lo ka aitwan kokiolong ← correct
#   D. Eiit iasama ka amukit aijany amonikin emisago
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q39 (Swahili) [Image 11 Questions]
#   Question: Picha hii inasema nini kuhusu jinsi wenyeji wanavyoshughulikia nguo?
#   A. Wanaiosha kwa mikono na kuitundika kwenye kamba ya nguo ← correct
#   B. Wanashona nguo zao wenyewe
#   C. Wanakusanya nguo na mara nyingi huziuza kwa ajili ya mapato
#   D. Wanatumia mashine za kufulia na kukaushia
#   Model output:    C
#   Predicted label: C  |  Correct label: A
#
# [✓] Q40 (English) [Image 11 Questions]
#   Question: What are the animals seen below the clothesline and what is their purpose?
#   A. They are Khaki Campbell and wander from the nearby Lake Victoria into the villagers backyard to feast on insects in the grass.
#   B. They are chickens and are often used for agricultural purposes. They provide eggs to use in recipes and eat for nutrients, and are often sold or harvested by farmers for their meat.
#   C. They are the Muscovy duck and are often kept by farmers and backyard poultry keepers. They are quiet birds used for their meat, eggs, and natural pest control. ← correct
#   D. They are an invasive duck species that eats surrounding vegetation and insects.
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q40 (Teso) [Image 11 Questions]
#   Question: Ani itisai lu eanywunitai koki ka aoroi lo ka iasama, ka ani aswamikebe?
#   A. Irai abangat na ka Muscovy na eeswamao nuka itunga ka ore keda amonikin iasama. Irai ikwenta lu emameun iisuben lu eeswamao nuka aanyam, akwito, keda aiki ikurut lu aponia bwan. ← correct
#   B. Irai abangat na ka areit na anyarait na aponia bwan na aanyam anya keda ikurut lu ka akwap.
#   C. Irai abangat na ka Khaki Campbell na elosit katenait anam lo ka Victoria aitun ikurut kotoma anya nuka itunga ka ore.
#   D. Irai ikoko lu eeswamao nuka aswam na ka akorobos. Emonikit akwito nuka aswam kotoma acurakin keda aanyam, ka amukit aijany nuka amonikin emisago.
#   Model output:    D
#   Predicted label: D  |  Correct label: A
#
# [✗] Q40 (Swahili) [Image 11 Questions]
#   Question: Ni wanyama gani wanaoonekana chini ya kamba ya nguo na madhumuni yao ni nini?
#   A. Wao ni bata aina ya Muscovy na mara nyingi hufugwa na wakulima na wafugaji wa kuku wa mashambani. Ni ndege tulivu wanaotumika kwa nyama yao, mayai, na udhibiti wa wadudu waharibifu wa asili. ← correct
#   B. Ni aina ya bata vamizi wanaokula mimea na wadudu wanaowazunguka.
#   C. Wao ni Khaki Campbell na hutangatanga kutoka Ziwa Victoria lililo karibu na kuingia kwenye uwanja wa nyuma wa wanakijiji ili kula wadudu kwenye nyasi.
#   D. Ni kuku na mara nyingi hutumika kwa madhumuni ya kilimo. Hutoa mayai ya kutumia katika mapishi na kula kwa ajili ya virutubisho, na mara nyingi huuzwa au kuvunwa na wakulima kwa ajili ya nyama yao.
#   Model output:    D
#   Predicted label: D  |  Correct label: A
#
# [✗] Q41 (English) [Image 12 Questions]
#   Question: What is this man doing?
#   A. Building a long wooden crate
#   B. Hammering steel onto a boat to build it ← correct
#   C. Repairing a wooden boat
#   D. Preparing to launch a boat into the water.
#   Model output:    C
#   Predicted label: C  |  Correct label: B
#
# [✗] Q41 (Teso) [Image 12 Questions]
#   Question: Ani aswam na ka okilen lo itodunitai kotoma epicha?
#   A. Areit aiki atuboi kotoma akipi
#   B. Ainyasum atuboi na ka akito na abila
#   C. Aduko atatago na ka akito na awoleto
#   D. Eiramit apira kidama ka atatago na ka atuboi aduko ← correct
#   Model output:    C
#   Predicted label: C  |  Correct label: D
#
# [✓] Q41 (Swahili) [Image 12 Questions]
#   Question: Mwanamume huyu anafanya nini?
#   A. Kupiga chuma kwenye mashua ili kuijenga ← correct
#   B. Kujiandaa kuzindua mashua ndani ya maji.
#   C. Kujenga kreti ndefu ya mbao
#   D. Kutengeneza mashua ya mbao
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✓] Q42 (English) [Image 12 Questions]
#   Question: This task will most likely take in total…
#   A. A few weeks to a few months ← correct
#   B. A day
#   C. A few days
#   D. A few years
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✗] Q42 (Teso) [Image 12 Questions]
#   Question: Aswam na, kotoma omarisin kere, elosit aitun...
#   A. Aparan iasama nepepe
#   B. Ikarin lu keditot bon
#   C. Iiapas lu keditot aitun iapas lu kapuaka ← correct
#   D. Aparanin lu keditot bon
#   Model output:    D
#   Predicted label: D  |  Correct label: C
#
# [✗] Q42 (Swahili) [Image 12 Questions]
#   Question: Kazi hii ina uwezekano mkubwa wa kuchukua jumla…
#   A. Siku moja
#   B. Siku chache
#   C. Miaka michache
#   D. Wiki chache hadi miezi michache ← correct
#   Model output:    C
#   Predicted label: C  |  Correct label: D
#
# [✓] Q43 (English) [Image 12 Questions]
#   Question: This man’s job is
#   A. A fisherman
#   B. A welder
#   C. An engineer
#   D. A boatmaker ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q43 (Teso) [Image 12 Questions]
#   Question: Ani aswam na ka okilen lo?
#   A. Ekaaswaman lo ka atuboin ← correct
#   B. Einjinia lo ka akwap
#   C. Ekaaswaman lo ka apira
#   D. Ekaalwaran lo ka igwenya
#   Model output:    B
#   Predicted label: B  |  Correct label: A
#
# [✗] Q43 (Swahili) [Image 12 Questions]
#   Question: Kazi ya mtu huyu ni
#   A. Mshonaji
#   B. Mtengenezaji wa mashua ← correct
#   C. Mhandisi
#   D. Mvuvi
#   Model output:    C
#   Predicted label: C  |  Correct label: B
#
# [✗] Q44 (English) [Image 13 Questions]
#   Question: This image shows the most common means of transportation are…
#   A. Boda-bodas, tuktuks, cars ← correct
#   B. Bikes and motorcycles
#   C. Motorcycles, minibuses, railways
#   D. Cars, motorcycles, ferries
#   Model output:    B
#   Predicted label: B  |  Correct label: A
#
# [✗] Q44 (Teso) [Image 13 Questions]
#   Question: Epicha lo itodunit eipone lo lo ka aiki lo apol elosit katenait...
#   A. Ibasikeli keda pikipiki
#   B. Pikipiki, matatu, keda egari lo ka apira lo agogong
#   C. Emuuga, pikipiki, keda atuboi na apol na ka akipi
#   D. Boda-boda, tuktuk, keda emuuga ← correct
#   Model output:    C
#   Predicted label: C  |  Correct label: D
#
# [✓] Q44 (Swahili) [Image 13 Questions]
#   Question: Picha hii inaonyesha njia za kawaida za usafiri ni…
#   A. Baiskeli na pikipiki
#   B. Pikipiki, mabasi madogo, reli
#   C. Boda-boda, tuktuks, magari ← correct
#   D. Magari, pikipiki, vivuko
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q45 (English) [Image 13 Questions]
#   Question: What are the motorcycle taxis in this image called?
#   A. Autobikes
#   B. Boda-bodas ← correct
#   C. Cruisers
#   D. Okada
#   Model output:    D
#   Predicted label: D  |  Correct label: B
#
# [✗] Q45 (Teso) [Image 13 Questions]
#   Question: Ani eboiet nuka pikipiki nuka itolosi itunga kotoma epicha lo?
#   A. Cruisers
#   B. Boda-boda ← correct
#   C. Autobikes
#   D. Okada
#   Model output:    D
#   Predicted label: D  |  Correct label: B
#
# [✗] Q45 (Swahili) [Image 13 Questions]
#   Question: Teksi za pikipiki katika picha hii zinaitwaje?
#   A. Okada
#   B. Boda-boda ← correct
#   C. Baiskeli za magari
#   D. Mabaharia
#   Model output:    A
#   Predicted label: A  |  Correct label: B
#
# [✓] Q46 (English) [Image 13 Questions]
#   Question: Which is a likely popular motorcycle model in this area?
#   A. Honda NC750X
#   B. Honda CG125 ← correct
#   C. BMW Motorrad
#   D. Ducati
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✓] Q46 (Teso) [Image 13 Questions]
#   Question: Ani eipone lo ka pikipiki lo amina ka lo apol aswam kotoma aibo na?
#   A. Honda CG125 ← correct
#   B. BMW Motorrad
#   C. Ducati
#   D. Honda NC750X
#   Model output:    A
#   Predicted label: A  |  Correct label: A
#
# [✓] Q46 (Swahili) [Image 13 Questions]
#   Question: Ni pikipiki gani inayoweza kuwa maarufu katika eneo hili?
#   A. Ducati
#   B. Honda NC750X
#   C. BMW Motorrad
#   D. Honda CG125 ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✓] Q47 (English) [Image 13 Questions]
#   Question: Delivery drivers most frequently drive
#   A. Cars
#   B. Motorcycles or bikes ← correct
#   C. Trucks
#   D. Tuktuks
#   Model output:    B
#   Predicted label: B  |  Correct label: B
#
# [✗] Q47 (Teso) [Image 13 Questions]
#   Question: Ekaaiton ka ekaatwan lo ka iasama katenait amukit aijany itoriti elosi aiki...
#   A. Emuuga
#   B. Emuuga lu apolok lu ka aiki iboro
#   C. Tuktuk
#   D. Pikipiki keda ibasikeli ← correct
#   Model output:    B
#   Predicted label: B  |  Correct label: D
#
# [✗] Q47 (Swahili) [Image 13 Questions]
#   Question: Madereva wa usafirishaji mara nyingi huendesha gari
#   A. Tuktuk
#   B. Malori
#   C. Pikipiki au pikipiki ← correct
#   D. Magari
#   Model output:    D
#   Predicted label: D  |  Correct label: C
#
# [✓] Q48 (English) [Image 14 Questions]
#   Question: This image was taken at a…
#   A. Water filling station
#   B. Mechanic stop/auto repair
#   C. Restaurant
#   D. Gas station ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✓] Q48 (Teso) [Image 14 Questions]
#   Question: Epicha lo aponia itelekunai kotoma...
#   A. Aibo na ka ainyasum emuuga
#   B. Aibo na ka aanyam
#   C. Aibo na ka amait amauta nuka emuuga ← correct
#   D. Aibo na ka amait akipi kotoma icupa
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q48 (Swahili) [Image 14 Questions]
#   Question: Picha hii ilipigwa katika…
#   A. Urekebishaji wa kituo/magari ya fundi
#   B. Kituo cha mafuta ← correct
#   C. Kituo cha kujaza maji
#   D. Mkahawa
#   Model output:    D
#   Predicted label: D  |  Correct label: B
#
# [✗] Q49 (English) [Image 14 Questions]
#   Question: What is in the bottle on the shelf?
#   A. Soda
#   B. Water
#   C. Laundry detergent
#   D. Soap / Multipurpose Cleaner ← correct
#   Model output:    B
#   Predicted label: B  |  Correct label: D
#
# [✗] Q49 (Teso) [Image 14 Questions]
#   Question: Ani ejaatatar kotoma ecupa kidama ka emesa lo ka aitwong?
#   A. Aboslo na ka ailwat iasama ka ore
#   B. Aboslo na ka ailwat iboro kere ← correct
#   C. Akipi
#   D. Soda lo amugit
#   Model output:    C
#   Predicted label: C  |  Correct label: B
#
# [✗] Q49 (Swahili) [Image 14 Questions]
#   Question: Ni nini kilichomo kwenye chupa kwenye rafu?
#   A. Sabuni / Kisafishaji cha Matumizi Mengi ← correct
#   B. Soda
#   C. Sabuni ya kufulia
#   D. Maji
#   Model output:    D
#   Predicted label: D  |  Correct label: A
#
# [✗] Q50 (English) [Image 14 Questions]
#   Question: What is the company featured on the red shirt?
#   A. Safaricom
#   B. KFC
#   C. National Oil Corporation of Kenya ← correct
#   D. Rubis Energy Kenya
#   Model output:    A
#   Predicted label: A  |  Correct label: C
#
# [✓] Q50 (Teso) [Image 14 Questions]
#   Question: Ani aodokin na ka ekaaswaman lo ejaatar keda eoroi lo arengan?
#   A. KFC
#   B. Safaricom
#   C. National Oil Corporation of Kenya ← correct
#   D. Rubis Energy Kenya
#   Model output:    C
#   Predicted label: C  |  Correct label: C
#
# [✗] Q50 (Swahili) [Image 14 Questions]
#   Question: Ni kampuni gani iliyoonyeshwa kwenye shati jekundu?
#   A. Nishati ya Rubis Kenya
#   B. Shirika la Kitaifa la Mafuta la Kenya ← correct
#   C. KFC
#   D. Safaricom
#   Model output:    A
#   Predicted label: A  |  Correct label: B
#
# [✓] Q51 (English) [Image 14 Questions]
#   Question: What is this person’s job?
#   A. Serving food to waiting customers
#   B. Driving taxis and being a mechanic
#   C. Cleaning up and being a janitor
#   D. Dispensing fuel and processing payments ← correct
#   Model output:    D
#   Predicted label: D  |  Correct label: D
#
# [✗] Q51 (Teso) [Image 14 Questions]
#   Question: Ani aswam na ka itunganan lo?
#   A. Amait amauta nuka emuuga keda amunokin emisago nuka amukit aijany ← correct
#   B. Aiki emuuga keda aswam na ka ainyasum iboro lu abila
#   C. Ailwat akwap keda aswam na ka aiki akorobos kere
#   D. Aiki aanyam katenait itunga lu eeswamao
#   Model output:    B
#   Predicted label: B  |  Correct label: A
#
# [✗] Q51 (Swahili) [Image 14 Questions]
#   Question: Kazi ya mtu huyu ni nini?
#   A. Kusafisha na kuwa mlinzi wa nyumba
#   B. Kuhudumia wateja wanaosubiri chakula
#   C. Kutoa mafuta na malipo ya usindikaji ← correct
#   D. Kuendesha teksi na kuwa fundi
#   Model output:    B
#   Predicted label: B  |  Correct label: C
#
# ============================================================
# Overall Accuracy:        40.52% (62/153)
# English Accuracy:        60.78% (31/51)
# Teso Accuracy:           35.29% (18/51)
# Swahili Accuracy:        25.49% (13/51)
# Random chance baseline:  25.00% (4 choices)
# ============================================================

# %% [markdown]
# ### Visualise Results (Trilingual)
#
# This section visualises the evaluation results, indicating correctness for English, Teso, and Swahili questions.

# %%
# ============================================================
# STEP 5: Visualise Results (Trilingual)
# ============================================================

# Create a figure with a grid of subplots for each sample, showing the image on top
# and English / Teso / Swahili results stacked underneath.

num_samples = len(samples)
fig, axes = plt.subplots(2, num_samples, figsize=(4 * num_samples, 8))

for i, sample in enumerate(samples):
    # Find predictions for this sample ID
    sample_preds = [p for p in detailed_predictions if p['sample_id'] == sample['ID']]

    english_pred = next((p for p in sample_preds if p['language'] == 'English'), None)
    teso_pred = next((p for p in sample_preds if p['language'] == 'Teso'), None)
    swa_pred = next((p for p in sample_preds if p['language'] == 'Swahili'), None)

    # Display image in the top row
    axes[0, i].imshow(sample["image"])
    axes[0, i].set_title(f"Q{sample['ID']} [{sample['Category']}]", fontsize=9)
    axes[0, i].axis("off")

    # Build a stacked results string for English / Teso / Swahili
    lines = []
    for label, pred in (("English", english_pred), ("Teso", teso_pred), ("Swahili", swa_pred)):
        if pred:
            status = "✓" if pred["is_correct"] else "✗"
            lines.append((f"{label}: {status}  Pred: {pred['predicted_label']} | Correct: {pred['correct_label']}",
                          "green" if pred["is_correct"] else "red"))
        else:
            lines.append((f"{label}: No Data", "gray"))

    axes[1, i].axis("off")
    y_positions = [0.8, 0.5, 0.2]
    for (text, color), y in zip(lines, y_positions):
        axes[1, i].text(0.5, y, text, fontsize=8, color=color, ha='center', va='center',
                        bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

plt.suptitle(
    f"SEA-MCQA Results (English, Teso & Swahili) — Aya Vision 8B — Overall Accuracy: {accuracy:.1f}% "
    f"(Random baseline: 25%)",
    fontsize=12
)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

print("\n" + "="*55)
print("     MCQA Evaluation Results (English/Teso/Swahili) — Aya Vision 8B")
print("="*55)

print(f"\nOverall Accuracy:        {accuracy:.2f}%")
print(f"Correct:                 "
      f"{sum(p['is_correct'] for p in detailed_predictions)}/{len(detailed_predictions)}")
print(f"Random chance baseline:  25.00% (4 choices)")
print("="*55)
